# %%
import logging
import re
import os
os.chdir('../code/')
import random

import torch
from torch.utils.data import DataLoader
# from tqdm import tqdm, trange
from tqdm.notebook import tqdm, trange
from transformers import (AdamW, AutoModelForSeq2SeqLM,
                          AutoTokenizer, get_linear_schedule_with_warmup)

# %%
from constants import *
from data_utils import (ABSADataset, filter_none, filter_invalid,
                        get_dataset, get_inputs, normalize_augment)
from model_utils import (prepare_constrained_tokens, prepare_tag_tokens)
from main import *
from data_utils import *

# %%
# Load arguments from the JSON file

import json
import argparse

arg_path = '../outputs/aste/cross_domain/run_aste/seed-42/laptop14-rest14/args.json'
with open(arg_path, 'r') as file:
    args_dict = json.load(file)

# Create a namespace from the dictionary
args = argparse.Namespace(**args_dict)

args.model_name_or_path = '../outputs/aste/cross_domain/run_aste/seed-42/laptop14-rest14/checkpoint-e24'
print(args)
# Out:
# Namespace(adam_epsilon=1e-08, beam=1, clear_model=True, commit=None, data_dir='../outputs/aste/cross_domain/run_aste/seed-42/laptop14-rest14/data', data_gene=True, data_gene_aug_num=None, data_gene_aug_ratio=None, data_gene_decode=None, data_gene_epochs=25, data_gene_extract=True, data_gene_extract_epochs=25, data_gene_extract_none_remove_ratio=0, data_gene_min_length=0, data_gene_none_remove_ratio=0, data_gene_none_word_num=1, data_gene_num_beam=1, data_gene_same_model=False, data_gene_top_p=0.9, data_gene_wt_constrained=True, dataset='cross_domain', device='cuda', do_eval=True, do_train=True, eval_batch_size=16, extract_model=None, gene_model=None, gradient_accumulation_steps=2, inference_dir='../outputs/aste/cross_domain/run_aste/seed-42/laptop14-rest14/inference', init_tag='english', learning_rate=0.0003, max_seq_length=128, model_filter=True, model_filter_skip_none=False, model_name_or_path='../outputs/aste/cross_domain/run_aste/seed-42/laptop14-rest14/checkpoint-e24', n_gpu='0', n_runs=1, name='run_aste', no_greedy=False, nrows=None, num_train_epochs=25, ori_tok_len=32100, output_dir='../outputs/aste/cross_domain/run_aste', paradigm='extraction-universal', pseudo=False, pseudo_skip_none=False, runned_folder=None, save_best=True, save_last_k=3, score_dir='../outputs/aste/cross_domain/run_aste/seed-42/laptop14-rest14/score', seed=42, seed_dir='../outputs/aste/cross_domain/run_aste/seed-42/laptop14-rest14', source_domain='laptop14', target_domain=['rest14'], task='aste', train_batch_size=2, train_by_pair=True, use_same_model=True, warmup_steps=0.0, weight_decay=0.0)

# %%
def openfile(path: str):
    with open(path, 'r') as file:
        lines = file.readlines()
    return [line.replace('\n','') for line in lines]


def input_output_pair(text:str):
    input, output = text.split('===>')
    return (input, output)

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(args.model_name_or_path).to(args.device)
tokenizer = AutoTokenizer.from_pretrained(args.model_name_or_path, use_fast=False)

# %%
txt_file_path = '../thai_data/laptop14/th/googletrans/train_aste_processed.txt'
row_list = openfile(txt_file_path)

input_list, target_list = [],[]
for row in tqdm(row_list):
    input, target = input_output_pair(row)
    input_list.append(input)
    target_list.append(target)
# Out:
#   0%|          | 0/906 [00:00<?, ?it/s]

# %%
input_list
# Out:
# ['ฉันชาร์จมันในเวลากลางคืนและข้ามสายไฟติดตัวไปด้วยเพราะอายุการใช้งานแบตเตอรี่ที่ดี ',
#  'มันมีคุณภาพสูงมี GUI นักฆ่ามีความเสถียรมากสามารถขยายได้สูงมีการใช้งานที่ดีมากใช้งานง่ายใช้งานง่ายและงดงามอย่างแน่นอน ',
#  'ง่ายต่อการเริ่มต้นและไม่ร้อนเกินไปเท่าแล็ปท็อปอื่น ๆ ',
#  'แล็ปท็อปที่ยอดเยี่ยมที่มีคุณสมบัติที่ยอดเยี่ยมมากมาย! ',
#  'คืนหนึ่งฉันปิดสิ่งที่น่าประหลาดใจหลังจากใช้มันในวันถัดไปฉันเปิดเครื่องไม่มี GUI หน้าจอมืดทั้งหมดไฟคงที่ไฟฮาร์ดไดรฟ์คงที่และไม่กระพริบเหมือนปกติ ',
#  'อย่างไรก็ตามท่าทางแบบมัลติทัชและพื้นที่ติดตามขนาดใหญ่ทำให้ไม่จำเป็นต้องใช้เมาส์ภายนอก (เว้นแต่คุณจะเล่นเกมอีกครั้ง) ',
#  'ฉันชอบวิธีที่ชุดซอฟต์แวร์ทั้งหมดทำงานร่วมกัน ',
#  'ความเร็วนั้นเหลือเชื่อและฉันก็พอใจมากกว่า ',
#  'ฉันแทบจะไม่สามารถใช้อุปกรณ์ USB ใด ๆ ได้เพราะพวกเขาจะไม่เชื่อมต่ออย่างถูกต้อง ',
#  'ในที่สุดเมื่อฉันมีทุกอย่างที่ทำงานกับซอฟต์แวร์ทั้งหมดของฉันที่ติดตั้งฉันเสียบอยู่ในหุ่นยนต์ของฉันเพื่อเติมเงินและระบบล่ม ',
#  'การจับคู่กับ iPhone เป็นความสุขที่บริสุทธิ์ - พูดคุยเกี่ยวกับการซิงค์ที่ไม่เจ็บปวด - ใช้เพื่อพาฉันไปตลอดกาล - ตอนนี้มันเป็นเรื่องง่าย ',
#  "ฉันยังได้รับโบนัสเพิ่มเติมของจอภาพ HD 30 '' ซึ่งช่วยขยายหน้าจอและทำให้ดวงตาของฉันสด! ",
#  'เครื่องจักรช้าในการบูตและบางครั้งล่มอย่างสมบูรณ์ ',
#  'หลังจากจ่ายเงินหลายร้อยดอลลาร์สำหรับบริการนี้มันน่าหงุดหงิดที่คุณไม่สามารถขอความช่วยเหลือได้หลังจากเวลาผ่านไปหลายชั่วโมง ',
#  'ฉันชอบระบบปฏิบัติการและซอฟต์แวร์ที่โหลดไว้ล่วงหน้า ',
#  'สิ่งที่ดีที่สุดเกี่ยวกับแล็ปท็อปนี้คือราคาพร้อมกับคุณสมบัติใหม่บางอย่าง ',
#  'คุณจะไม่สามารถพูดคุยกับบริการรับประกันอเมริกันอยู่นอกประเทศ ',
#  'แต่ตอนนี้ฉันได้ตระหนักถึงปัญหาของแบรนด์นี้ ',
#  'ก็ดังเมื่อแฟนวิ่ง ',
#  'ดูเหมือนว่าจะมีปัญหากับฮาร์ดดิสก์เนื่องจาก Windows โหลดบางครั้ง แต่อ้างว่าไม่สามารถค้นหาไดรเวอร์หรือไฟล์ใด ๆ ได้ ',
#  'เมื่อพูดถึงเบราว์เซอร์ก็มีปัญหาเช่นกัน ',
#  'แป้นพิมพ์ลื่นเกินไป ',
#  'มันเหมือน 9 ปอนด์ แต่ถ้าคุณสามารถมองผ่านมันได้มันก็ยอดเยี่ยมมาก! ',
#  'มันเร็วพอที่จะเปิดโปรแกรมเดียวตามที่เปิดสิบหก ',
#  'ยังอยู่ภายใต้ Warrenty เรียกว่าโตชิบาไม่มีความช่วยเหลือเลย ',
#  'คุณภาพที่น่าทึ่ง! ',
#  'หนึ่งเดือนที่ผ่านมาเมนบอร์ดที่เพิ่งเสียชีวิตเพิ่งเสียชีวิต ',
#  'ระบบที่มาพร้อมกับไม่ทำงานอย่างถูกต้องดังนั้นเมื่อพยายามแก้ไขปัญหากับมันมันเริ่มไม่ทำงานเลย ',
#  'จากนั้นหลังจาก 4 เดือนหรือมากกว่านั้นเครื่องชาร์จหยุดทำงานดังนั้นฉันจึงถูกบังคับให้ออกไปซื้อฮาร์ดแวร์ใหม่เพื่อให้คอมพิวเตอร์เครื่องนี้ทำงานอยู่ ',
#  'หากเว็บไซต์เคยค้าง (ซึ่งหายาก) มันง่ายที่จะบังคับให้เลิก ',
#  'ฉันยังสนุกกับความจริงที่ว่าแล็ปท็อป MacBook Pro ของฉันช่วยให้ฉันสามารถเรียกใช้ Windows 7 ได้โดยใช้โปรแกรม VMware ',
#  'ฉันต้องการซื้อการรับประกันเพิ่มเติมและพวกเขาปฏิเสธเพราะพวกเขารู้ว่ามันเป็นปัญหา ',
#  'เราอัพเกรดหน่วยความจำเป็นสี่กิกะไบต์เพื่อใช้ประโยชน์จากการเพิ่มประสิทธิภาพของประสิทธิภาพ ',
#  'ความจริงก็คือมันร้อนขึ้นอย่างรวดเร็วและใช้เวลานานเกินไปที่จะทำสิ่งง่าย ๆ เช่นเปิดโฟลเดอร์เอกสารของฉัน ',
#  'ฉันมักจะใช้พีซีและรู้สึกหงุดหงิดอย่างต่อเนื่องกับการกระแทกและระบบปฏิบัติการที่ออกแบบมาไม่ดีซึ่งไม่เคยใช้งานง่ายมาก ',
#  'จากนั้นภายใน 5 เดือนเครื่องชาร์จก็ออกมาหาฉัน ',
#  'และถ้าคุณมี iPhone หรือ iPod Touch คุณสามารถเชื่อมต่อและดาวน์โหลดเพลงด้วยความเร็วสูง ',
#  'ฉันชอบทัชแพดแก้ว ',
#  'ฉันยังคงใช้คอมพิวเตอร์อีกครั้งและพวกเขาแทนที่ฮาร์ดไดรฟ์และบอร์ดแม่อีกครั้ง ',
#  'จากนั้น HP จะส่งมันกลับมาให้ฉันด้วยฮาร์ดแวร์ที่เมาแล้วไม่สามารถเชื่อมต่อได้ ',
#  'โอ้ใช่อย่าลืมการจัดส่งที่มีราคาแพงไปและกลับจาก HP ',
#  'ทุกอย่างใช้งานง่ายซอฟต์แวร์ Mac นั้นง่ายกว่าซอฟต์แวร์ Microsoft มาก ',
#  'และถ้าคุณเขียนจำนวนมากการแก้ไขเป็นปัญหาเนื่องจากไม่มีคีย์ลบไปข้างหน้า ',
#  'ความสะดวกในการใช้งานและบริการชั้นนำจาก Apple- ไม่ว่าจะเป็นความช่วยเหลือทางโทรศัพท์หรือท้องไปจนถึงแถบอัจฉริยะ- ไม่สามารถเอาชนะได้ ',
#  'มันมีอายุการใช้งานแบตเตอรี่ 10 ชั่วโมงเมื่อคุณทำการท่องเว็บและการแก้ไขคำทำให้สมบูรณ์แบบสำหรับห้องเรียนหรือสำนักงานและในแง่ของการเล่นเกมและภาพยนตร์ที่เล่นมันจะมีอายุการใช้งานแบตเตอรี่เพียง 5 ชั่วโมง ',
#  'Acer ได้ตั้งค่าฉันด้วยแผ่นดิสก์การกู้คืนฟรีเมื่อพวกเขาพร้อมตั้งแต่ฉันถาม ',
#  'การเปิดใช้งานตัวจับเวลาแบตเตอรี่นั้นไร้ประโยชน์ ',
#  'ไม่จำเป็นต้องซื้อการป้องกันไวรัสสำหรับ Mac ซึ่งช่วยให้ฉันประหยัดเวลาและเงินได้มาก ',
#  'แต่เราจ่ายเงินให้กับบลูทู ธ และไม่มีเลย ',
#  'มันน่าเชื่อถือเสมอไม่เคยมีข้อผิดพลาดและตอบสนองได้ดี ',
#  'พวกเขาต้องเปลี่ยนเมนบอร์ดในเดือนเมษายน ',
#  'นอกจากนี้หากคุณต้องการพูดคุยกับตัวแทนที่ Microsoft มีค่าใช้จ่ายซึ่งฉันเชื่อว่าเป็นการปล้นเนื่องจากคุณถูกเรียกเก็บเงินจำนวนมหาศาลสำหรับระบบที่ออกแบบมาไม่ดีซึ่งคนส่วนใหญ่จะไปกับ XP ถ้าทำได้ ',
#  'ฉันรัก Windows 7 ซึ่งเป็นการปรับปรุงที่กว้างขวางเหนือ Vista ',
#  'การก่อความเสียหายของลูกค้าของ Dell เป็นการดูถูกลูกค้าของมันที่จ่ายเงินที่ดีสำหรับผลิตภัณฑ์ Shoddy ',
#  'หลังจากพูดคุยกับพนักงานขายที่มีความรู้มากฉันเลือก MacBook Pro มากกว่า White MacBook ',
#  'หากคุณต้องการระบบที่ดีและไม่จำเป็นต้องเรียกใช้แอพพลิเคชั่น Windows ให้ไปกับ Apple ',
#  'คุณไม่จำเป็นต้องใช้เงินไปกับโปรแกรมไวรัสที่ไม่มีประสิทธิภาพบางอย่างที่ต้องได้รับการปรับปรุงทุกเดือนและระบายกระเป๋าเงินของคุณอย่างต่อเนื่อง ',
#  'สีของมันเจ๋งมาก ',
#  'กุญแจล้วนอยู่ในสถานที่แปลก ๆ และมีขนาดใหญ่เกินไปสำหรับวิธีการออกแบบ ',
#  'ใช่ MAC เป็นเงินมากกว่าแล็ปท็อปเฉลี่ยอยู่ที่นั่น แต่ไม่มีการเปรียบเทียบในสไตล์ความเร็วและปัจจัยที่ยอดเยี่ยม ',
#  'และไม่ต้องพูดถึงหลังจากใช้มันสักสองสามเดือนหรือมากกว่านั้นแบตเตอรี่จะค่อยๆชาร์จน้อยลงเรื่อย ๆ จนกว่าคุณจะไม่สามารถทิ้งไว้ได้นานกว่า 5 นาทีโดยไม่มีสิ่งที่กำลังจะตาย ',
#  'Best Buy - 5 Stars + + + (การขาย, บริการ, การเคารพต่อชายชราที่ไม่คุ้นเคยกับเทคโนโลยี) คอมพิวเตอร์ Dell - 3 ดาวสนับสนุน Dell - เป็นหนี้ฉันคู่หนึ่ง ',
#  'ไม่มีการร้องเรียนเกี่ยวกับเดสก์ท็อปของพวกเขาและอาจเป็นเพราะมันอยู่บนเดสก์ท็อปของคุณและคุณไม่ได้พกพาไปรอบ ๆ ซึ่งสามารถเก็บฮาร์ดไดรฟ์หรือเมนบอร์ด ',
#  'ใช่พวกเขามีค่าใช้จ่ายมากขึ้น แต่พวกเขามากกว่าการชดเชยด้วยความเร็วคุณภาพการก่อสร้างและอายุยืน ',
#  'มันแพงกว่าแล็ปท็อปพีซีส่วนใหญ่อย่างแน่นอน แต่ความสะดวกในการใช้งานการรักษาความปลอดภัยและปัญหาที่น้อยที่สุดที่เกิดขึ้นทำให้มันคุ้มค่ากับราคาที่ดี ',
#  'มันติดอยู่ตลอดเวลาที่คุณใช้และคุณต้องแตะมันเพื่อให้มันทำงานได้ ',
#  'ซอฟต์แวร์ที่โหลดไว้ล่วงหน้าจำนวนมาก ',
#  'ฉันหวังว่ามันจะมีเว็บแคม แต่ก็จะสมบูรณ์แบบ! ',
#  'อีกสิ่งหนึ่งที่ฉันอาจเพิ่มคืออายุการใช้งานแบตเตอรี่นั้นยอดเยี่ยม ',
#  'ข้อเสียเปรียบอย่างหนึ่งฉันหวังว่ากุญแจจะเป็นไฟ ',
#  'ฉันหวังว่าปริมาณจะดังขึ้นและเมาส์ไม่ได้แตกหลังจากผ่านไปเพียงหนึ่งเดือน ',
#  'ฉันเล่นเกมสบาย ๆ ออนไลน์มากมายและทัชแพดตอบสนองได้ดีมาก ',
#  'มันเป็นทุกสิ่งที่ฉันหวังว่ามันจะมาจากมุมมองและความรู้สึก แต่อย่างใดที่แข็งแกร่งขึ้นอีกเล็กน้อย ',
#  'ความจริงเพียงอย่างเดียวที่ฉันไม่ชอบเกี่ยวกับแอปเปิ้ลคือพวกเขาใช้ Safari และฉันไม่ได้ใช้ Safari แต่หลังจากฉันติดตั้ง Mozilla Firefox ฉันรักทุก ๆ เรื่องเกี่ยวกับเรื่องนี้ ',
#  'แบตเตอรี่ที่ยอดเยี่ยมความเร็วจอแสดงผล ',
#  'การส่งมอบเร็วและฉันจะไม่ลังเลที่จะซื้อแล็ปท็อปนี้อีก ',
#  'ฉันประทับใจกับอายุการใช้งานแบตเตอรี่และประสิทธิภาพสำหรับหน่วยความจำจำนวนเล็กน้อย ',
#  'แอปพลิเคชันของมันยอดเยี่ยมมากรวมถึงการเปลี่ยนสำหรับ Microsoft Office ',
#  'ฉันได้รับมันกลับมาและเว็บแคมในตัวของฉันและไมค์ในตัวก็สั้นลงทุกครั้งที่ฉันสัมผัสฝา (โปรดทราบว่านี่เป็นวิธีการสื่อสารกับคู่หมั้นของฉันที่ถูกนำไปใช้) แต่ฉันต้องทนทุกข์ทรมานรีเซ็ตคอมพิวเตอร์เพื่อให้สามารถใช้กล้องและไมค์ของฉันได้ตลอดเวลาที่ออกไป ',
#  'บอร์ดมีตัวเชื่อมต่อที่ไม่ดีกับแหล่งจ่ายไฟและไม่นานหลังจากการรับประกันหมดอายุแหล่งจ่ายไฟจะเริ่มมีปัญหา ',
#  'พ่อของฉันมีหนึ่งในโทชิบาครั้งแรกที่เคยทำใช่ตอนนี้มันช้าไปหน่อย แต่ก็ยังทำงานได้ดีและฉันก็ติดกับอีเธอร์เน็ตของฉัน! ',
#  'ส่วนใหญ่ฉันชอบคุณสมบัติการลากและวาง ',
#  'โอ้ใช่แล้วถ้าเว็บแคมแฟนซีแบ่งเดาว่าคุณต้องส่งใครไปเพื่อรับการแก้ไข? ',
#  'ฉันสั่งซื้อผ่าน MacMall ซึ่งช่วยให้ฉันประหยัดภาษีการขายที่ฉันจะซื้อในท้องถิ่น ',
#  'แน่นอนว่าฉันยังมีแพ็คเกจซอฟต์แวร์ที่ยอดเยี่ยมหลายชุดที่มาฟรีรวมถึง iWork, GarageBand และ Imovie ',
#  'หน้าจอมีขนาดใหญ่มากและชัดเจนด้วยสีและความละเอียดที่น่าทึ่ง ',
#  'หลังจากเป็นเจ้าของ MacBook Pro มานานกว่าหนึ่งปีจอภาพก็ตายไปแล้ว ',
#  'แบรนด์ของ iTunes เพิ่งจะฝังแน่นอยู่ในพจนานุกรมของเราในตอนนี้ แต่โปรดจำไว้ว่า Apple เริ่มต้นมันทั้งหมด ',
#  'ขนาด: ฉันรู้ว่า 13 มีขนาดเล็ก (โดยเฉพาะอย่างยิ่งสำหรับการเปลี่ยนเดสก์ท็อป) แต่มีจอมอนิเตอร์ภายนอกใครสนใจ ',
#  'จอแสดงผลมีความสว่างอย่างไม่น่าเชื่อสว่างกว่า PowerBook ของฉันและกรอบมาก ',
#  'เมนูเริ่มต้นไม่ใช่สิ่งที่ง่ายที่สุดในการนำทางเนื่องจากการซ้อน ',
#  'ชอบพื้นผิวที่มีพื้นผิวซึ่งไม่แสดงลายนิ้วมือ ',
#  'หน้าจอสว่างและแป้นพิมพ์ก็ดี ',
#  'แต่เครื่องจักรนั้นยอดเยี่ยมและ Ilife นั้นยอดเยี่ยมและฉันชอบ Snow Leopard X ',
#  'ฉันคิดว่าการเรียนรู้ Mac OS นั้นยาก แต่ก็สามารถเลือกได้อย่างง่ายดายหากคุณคุ้นเคยกับพีซี ',
#  'ใช้งานง่ายและมีน้ำหนักเบา ',
#  'พวกเขายังมีอายุการใช้งานที่ยาวนานกว่าคอมพิวเตอร์เครื่องอื่น (ฉันมีเพื่อนหลายคนที่ยังคงใช้ Apple Powerbooks รุ่นเก่า) ',
#  'หากคุณตรวจสอบคุณจะพบสมุดบันทึกเดียวกันกับพอร์ตที่หายไปข้างต้นและโปรเซสเซอร์ Dual Core AMD หรือ Intel ',
#  'แล็ปท็อปเครื่องนี้เป็นราคาที่ยอดเยี่ยมและดูเพรียวบาง ',
#  'โดยเฉพาะอย่างยิ่งฉันชอบแป้นพิมพ์ที่มีคีย์ประเภทชิคเล็ต ',
#  'ฉันซื้อตัวป้องกันสำหรับคีย์แผ่นของฉันและมันใช้งานได้ดี :) ',
#  'สายไฟการชาร์จพลังงานของปลั๊กอินแม่เหล็กนั้นยอดเยี่ยม (ฉันยังนำไปทดสอบโดยบังเอิญ) - นวัตกรรมที่ยอดเยี่ยม! ',
#  'ในขณะที่ Saving Grace ของ Apple คือความจริงที่ว่าอย่างน้อยพวกเขาก็ยืนอยู่ข้างหลังผลิตภัณฑ์ของพวกเขาและการสนับสนุนของพวกเขานั้นยอดเยี่ยมมันคงจะดีถ้าผลิตภัณฑ์ของพวกเขามีความน่าเชื่อถือมากกว่าที่จะพิสูจน์พรีเมี่ยม ',
#  'สิ่งที่ดีเท่านั้นคือคุณภาพของกราฟิก ',
#  'ปัญหาการล็อคอื่น ๆ มาจากสาเหตุมากมายซึ่งพบได้บ่อยที่สุดคือ Appleworks เวอร์ชันที่เสียหายซึ่งสามารถทำให้เบราว์เซอร์ไร้ประโยชน์ได้ ',
#  'สีสึกหรอได้ง่ายเนื่องจากคีย์บอร์ดอยู่ไกลกว่าปกติ ',
#  'ร้านค้าให้เกียรติการรับประกันของพวกเขาและแสดงความคิดเห็นว่าพวกเขาไม่ได้แนะนำแบรนด์ HP เนื่องจากปัญหาเกี่ยวกับการรับประกันของพวกเขา ',
#  'พวกเขาส่งกล่องออกทันทีเพื่อให้ฉันส่งคอมพิวเตอร์ของฉันพวกเขาจ่ายค่าไปรษณีย์และอะไรก็ตาม แต่เมื่อฉันได้คอมพิวเตอร์กลับมามันก็ยังไม่ถูกต้องและตอนนี้ไดรฟ์ซีดีของฉันไม่ได้อ่านอะไรเลย! ',
#  'แต่ขนาดหน้าจอนั้นไม่ได้เลวร้ายสำหรับอีเมลและการท่องเว็บ ',
#  'ใน PowerBook G4 ของฉันฉันจะไม่ใช้แทร็กแพดฉันจะใช้เมาส์ภายนอกเพราะฉันไม่ชอบแทร็กแพด ',
#  'คอมพิวเตอร์เครื่องนี้ไม่ได้ทำเช่นนั้นกับเกมบางเกมที่ไม่ได้เล่นบ้างและมันก็ร้อนเกินไปในขณะที่เล่นเกม ',
#  "ใช่แน่นอนกางเกง Smarty `` Fix It Now '') - เมื่อเทียบกับรุ่นต้นปี 2011 ที่ฉันเห็นแอปพลิเคชัน inbuilt ล้มเหลวและมันกระตุ้นให้ฉันส่งรายงานไปยัง Apple (ซึ่งฉันทำทันที) ",
#  'ร่างกายมีราคาถูกเล็กน้อยดังนั้นจึงน่าสนใจที่จะเห็นว่ามันมีอยู่นานแค่ไหน ',
#  'ด้วย Mac คุณไม่ต้องกังวลเกี่ยวกับซอฟต์แวร์ป้องกันไวรัสหรือไฟร์วอลล์มันยอดเยี่ยมมาก ',
#  'ดีใจมากที่ฉันซื้อมันเน็ตบุ๊กที่ยอดเยี่ยมราคาต่ำ ',
#  'ทีม Apple ยังช่วยคุณได้ดีมากเมื่อเลือกคอมพิวเตอร์ที่เหมาะกับคุณ :) ',
#  'ฉันคิดว่าส่วนหนึ่งของปัญหาเกี่ยวกับคอมพิวเตอร์เครื่องนี้คือ Vista แต่ฉันรู้ว่า Vista ไม่ใช่ปัญหาทั้งหมดเพราะการซื้อครั้งล่าสุดของฉันคือ Acer ของฉันและมันก็มี Vista (ฉันควรรอสองสามเดือนเพื่อรับระบบปฏิบัติการต่อไป). ',
#  'วิดีโอแชทเป็นสิ่งเดียวที่ไม่สามารถทำได้ แต่ฉันแน่ใจว่าเมื่อพวกเขาอัปเดตเวอร์ชันถัดไปในหนังสือ MacBook คุณภาพของมันจะดีกว่า ',
#  'ประสบการณ์ทั้งหมดนั้นไร้สาระที่เราส่งมาและหลังจากพวกเขาบอกเราว่าเราต้องจ่าย $ 175 เพื่อแก้ไขมันเราเป็นเหมือนเราจะใช้เมาส์พกพาซึ่งจะถูกกว่า แต่พวกเขาปฏิเสธที่จะส่งแล็ปท็อปกลับจนกว่าเราจ่ายเงิน $ 175 และได้รับการแก้ไข ',
#  'ช่องระบายอากาศของพัดลมไปด้านข้างดังนั้นจึงไม่จำเป็นต้องใช้แผ่นระบายความร้อนคุณสมบัติที่ยอดเยี่ยม! ',
#  'ฉันใช้ Mac ของฉันตลอดเวลาฉันชอบซอฟต์แวร์วิธีการใช้เวลาสั้น ๆ ในการโหลดสิ่งต่าง ๆ ใช้งานได้ง่ายแค่ไหนและส่วนใหญ่ที่คุณไม่ต้องกังวลเกี่ยวกับไวรัส ',
#  'เสียเวลาติดตั้งอย่างน้อย 8 ชั่วโมง ',
#  'มันเกินความคาดหวังของฉันสำหรับพลังงานการจัดเก็บและความสามารถ ',
#  'ฉันสนุกกับมันและคุณภาพที่ให้นั้นยอดเยี่ยมมาก! ',
#  'พอจะพูดได้ว่า MacBook Pro ของฉันทำให้ฉันมีอายุการใช้งานแบตเตอรี่ที่ยาวนานและความเร็วที่น่าทึ่ง ',
#  'ระบบปฏิบัติการยังใช้งานง่ายมากแม้สำหรับผู้ที่เปลี่ยนจากพีซีด้วยการฝึกฝนเล็กน้อยคุณสามารถใช้ประโยชน์จากระบบปฏิบัติการนี้ได้อย่างเต็มที่! ',
#  'iTunes เป็นโปรแกรมการจัดการดนตรีที่มีประโยชน์และเป็นสิ่งจำเป็นสำหรับทุกคนที่มี iPod ',
#  'โปรแกรมใช้งานง่ายและรวดเร็วในการประมวลผลคอมพิวเตอร์นี้ทำงานได้อย่างมีเสน่ห์ ',
#  'ฝ่ายสนับสนุนด้านเทคนิคบอกฉันว่าปัญหาหลังคือปัญหาแหล่งจ่ายไฟและเสนอให้แก้ไขหากเกิดขึ้นอีกครั้ง ',
#  'ขายให้กับเน็ตบุ๊กโดยไม่ต้องเสียสละขนาด ',
#  'Windows XP SP2 ทำให้เกิดปัญหามากมายบนคอมพิวเตอร์ดังนั้นฉันจึงต้องลบออก ',
#  'นี่เป็นปัญหาที่สองของฉันและปัญหาเดียวกันการ์ดวิดีโอที่ไม่ดีไม่น่าเชื่อถือโดยรวมนี่จะเป็นครั้งที่สองของฉันที่จะส่งคืนแล็ปท็อปนี้กลับไปที่ Best Buy ',
#  'ด้วยกราฟิกที่ยอดเยี่ยมและการรักษาความปลอดภัยมันสมบูรณ์แบบ! ',
#  'แล็ปท็อปติดตั้งง่ายมาก ',
#  'ฉันแนะนำสำหรับการประมวลผลคำและผู้ใช้อินเทอร์เน็ต ',
#  'เนื่องจากฉันมีคอมพิวเตอร์เครื่องนี้ฉันใช้แทร็กแพดเท่านั้นเพราะมันดีและราบรื่นมาก ',
#  'อายุการใช้งานแบตเตอรี่ที่ยาวนานขึ้นจะยอดเยี่ยม - แต่มันก็ตรงกับข้อมูลจำเพาะของมันค่อนข้างง่าย ',
#  'ใครจะไม่รักเครื่องเขียนดีวีดี 80 กิกะไบต์ HD และชิปกราฟิกใหม่แม้ว่าในไม่ช้าฉันจะค้นพบว่ามีเหตุผลที่เครื่องจักร Sony และ Toshiba ที่กำหนดค่าในทำนองเดียวกันมีค่าใช้จ่ายมากขึ้น: พวกเขาใช้ส่วนประกอบที่มีคุณภาพสูงกว่าซึ่งเร็วขึ้นกำหนดค่าได้ดีขึ้น ',
#  'ตัวคอมพิวเตอร์นั้นเร็ววิ่งได้อย่างราบรื่นและไม่มีปัญหา ',
#  'ชอบราคาและการดำเนินงาน ',
#  'แบรนด์ถูกทำให้มัวหมองในใจฉัน ',
#  'นี่อาจเป็นเพราะการต่อสายดินที่ไม่ดีและการแยกระหว่างส่วนประกอบและฉันหวังว่ามันจะได้รับการแก้ไขด้วยตัวแยกลูปพื้นดิน แต่ฉันก็ยังคาดหวังคุณภาพของผลิตภัณฑ์ที่ดีกว่าสำหรับช่วงราคานี้ ',
#  'ฉันมีมันประมาณ 1 1/2 และใช่ฉันมีปัญหากับการรับประกันหนึ่งเดือน ',
#  'เมื่อเปิดออกแล้วขอบนำจะคมมีดโกน ',
#  'เสียงสูงสุดไม่ดังเท่าที่ควร ',
#  'ฉันโหลด Windows 7 ผ่าน bootcamp และทำงานได้อย่างไร้ที่ติ! ',
#  'แล็ปท็อปที่ยอดเยี่ยมสำหรับราคาทำงานได้ดีกับเกมแอ็คชั่นแพ็ค ',
#  'แม้ว่าราคาจะสูงขึ้นจากนั้นแล็ปท็อป Dell แต่ MacBooks ก็คุ้มค่ากับแป้ง ',
#  'แล้วถ้าแล็ปท็อป/โทรศัพท์มือถือดูเก๋ไก๋และเท่ห์ล่ะ?การสนับสนุนการขายหลังนั้นแย่มาก ',
#  'ฉันเกลียดหน้าจอแสดงผลและฉันได้ทำทุกอย่างที่ฉันสามารถเปลี่ยนแปลงได้ ',
#  'ฉันชอบ Acer Arcade แต่สิ่งเหล่านี้เป็นเพียงสองสิ่งที่ฉันชอบเกี่ยวกับแล็ปท็อปนี้ ',
#  'ยังไม่ต้องการการสนับสนุนลูกค้าใด ๆ ด้วยสิ่งนี้ แต่สำหรับฉันนั่นเป็นสิ่งที่ยอดเยี่ยมซึ่งเป็นการก้าวกระโดดก่อนพีซีในความคิดของฉัน ',
#  'ฉันมอบให้ลูกสาวของฉันเพราะฉันเพิ่งเกลียดหน้าจอเกลียดที่ไม่มีไดรฟ์ซีดีให้เล่นซีดีอย่างน้อยเมื่อฉันต้องการฟังเพลงและทำงานโรงเรียน ',
#  'มันก็เงียบมากเช่นกันซึ่งเป็นข้อดี ',
#  'แต่มันมีข้อบกพร่องในการออกแบบที่สำคัญ ',
#  'มันหนักขนาดใหญ่และยากที่จะพกพาเพราะขนาด ',
#  'เกมที่รวมเป็นเกมที่ดีมาก ',
#  'คอมพิวเตอร์เครื่องนี้จะคงอยู่กับคุณอย่างน้อย 7 ปีนั่นคือชีวิตที่น่าตื่นตาตื่นใจ ',
#  'สามหนังสือ Mac มีข้อได้เปรียบเหนือพีซีด้วยระบบปฏิบัติการที่ใช้ Linux มีปัญหาน้อยมากเกี่ยวกับประสิทธิภาพของระบบเมื่อมาถึง Mac ',
#  'Mac ใช้งานง่ายมากและมันก็สมเหตุสมผล ',
#  'ใช้งานง่ายกว่ามาก ',
#  'เป็นเรื่องดีมากที่ไม่ต้องกังวลเกี่ยวกับเรื่องนี้และค่าใช้จ่ายเพิ่มเติมที่มาพร้อมกับการป้องกันไวรัสที่จำเป็นบนพีซี ',
#  'โปรเซสเซอร์กรีดร้องและเนื่องจากวิธีที่ไม่ซ้ำกันที่ Apple OSX 16 ฟังก์ชั่นกราฟิกส่วนใหญ่จะถูกกำหนดเส้นทางผ่านฮาร์ดแวร์มากกว่าซอฟต์แวร์ ',
#  'ฉันต้องการบางสิ่งที่มีโปรเซสเซอร์ Intel Core ใหม่และพอร์ต HDMI เพื่อที่เราจะได้เชื่อมต่อกับทีวีของเราโดยตรง ',
#  'ราคาพรีเมี่ยมนั้นค่อนข้างมาก แต่เมื่อคุณเริ่มดูคุณสมบัติมันก็คุ้มค่ากับเงินสดที่เพิ่มเข้ามา ',
#  'ฉันไม่สามารถพูดได้ว่าฉันพอใจกับผลิตภัณฑ์ของพวกเขาและช่วยเหลือหลังการขายมากแค่ไหน ',
#  'ฉันเชื่อมต่อไดรฟ์ภายนอก LaCie 2Big ผ่านอินเตอร์เฟส Firewire 800 ซึ่งมีประโยชน์สำหรับ Time Machine ',
#  'ฉันยินดีเป็นอย่างยิ่งกับดาวเทียม Toshiba ของฉันฉันชอบคุณสมบัติพิเศษฉันชอบ Windows 7 Home Premium ',
#  'อายุการใช้งานแบตเตอรี่สั้นกว่าที่คาดไว้ ',
#  'แป้นพิมพ์อยู่ด้านบน ',
#  'ภาพนั้นยอดเยี่ยมและเสียงก็ยอดเยี่ยม ',
#  'มันคุ้มค่ากับเงินที่ต้องเสียค่าใช้จ่ายการลงทุนที่ดีมาก ',
#  'การอัพเกรดจาก Windows 7 Starter, ผ่าน Windows 7 Home Premium เป็น Windows 7 Professional เป็นอย่างรวดเร็ว ',
#  'ฉันอัพเกรด MacBook เก่าเป็นสิงโตดังนั้นฉันจึงรู้ว่าฉันได้รับอะไร แต่ไม่สามารถเพลิดเพลินไปกับคุณสมบัติมัลติทัชใหม่ที่ยอดเยี่ยมได้ ',
#  'หน้าจอมีเสน่ห์เล็กน้อยและฉันเกลียดปุ่มคลิก แต่ฉันคุ้นเคยกับมัน ',
#  'ไม่ต้องพูดถึงอายุการใช้งานแบตเตอรี่นั้นน่าทึ่งมาก ',
#  'ตอนนี้สำหรับปัญหาฮาร์ดแวร์ ',
#  'มันเร็วและมีอายุการใช้งานแบตเตอรี่ที่ยอดเยี่ยม ',
#  'รวมการดูแลของแอปเปิ้ล ',
#  'หน้าต่างก็ค่อนข้างไม่มั่นคงบนเท้าและมีความอ่อนไหวต่อข้อบกพร่องหลายอย่าง ',
#  'อย่าซื้อคอมพิวเตอร์เกตเวย์พวกเขาเป็นขยะและ บริษัท รับประกันนั้นน่ากลัว ',
#  'ส่วนที่ไม่ดีเพียงอย่างเดียวคือขนาด / น้ำหนัก ',
#  'แบตเตอรี่เล็ก ๆ น้อย ๆ ที่มันมีอยู่เพียงประมาณหนึ่งชั่วโมงในขณะที่มีมันอยู่บนเดสก์ท็อป ',
#  'ฉันชอบร่างกายอลูมิเนียม ',
#  'มันดีสำหรับการเล่นแอพของฉันบน Facebook หรือดูหนัง ',
#  'จากคุณภาพการสร้างจนถึงประสิทธิภาพทุกอย่างเกี่ยวกับมันได้รับการย่อยจากสิ่งที่ฉันคาดหวังจาก Apple ',
#  'ฉันชอบท่าเรือที่ฉันสามารถวางไฟล์ที่ด้านบนของโปรแกรมเฉพาะและโปรแกรมจะเปิดไฟล์นั้น ',
#  'ทุกอย่างเกี่ยวกับคอมพิวเตอร์เป็นสิ่งที่ดีเพียงแค่หยุดทำงานไม่ได้ ',
#  'มันเป็นคอมพิวเตอร์ที่ยอดเยี่ยมที่มีราคาน้อยกว่าหนึ่งพันเหรียญก่อนหักภาษี ',
#  'การรอให้ i7 คุ้มค่ามากคุ้มค่าสำหรับราคา ',
#  'รองเท้าบูทเร็วและวิ่งได้ดี! ',
#  'น้ำหนักเบาและหน้าจอสวยงาม! ',
#  'MacBook มาถึงการบรรจุคู่ที่ดีและปิดผนึกในกล่องฟังก์ชั่นทั้งหมดใช้งานได้ดี ',
#  'พวกเขาบอกว่าขออภัยจากการรับประกัน ',
#  'หลังจากมีแล็ปท็อปพีซีสองเครื่องตายด้วยในช่วง 3 ปีที่ผ่านมาฉันถูกพาไปที่ Apple Display ที่ Best Buy โดยการออกแบบที่ทันสมัยและสัญญาของปัญหาเทคโนโลยีที่น้อยลง ',
#  'บริการที่ฉันได้รับจากโตชิบาไปเหนือกว่าการเรียกร้อง ',
#  'มีคอมพิวเตอร์ที่มีราคาสูงกว่าจำนวนมากล้มเหลวและเผาไหม้มานานก่อนที่เคยใช้หน่วยความจำและความเร็วที่ยอดเยี่ยม ฯลฯ ',
#  'ฉันอยากจะแนะนำเพียงเพราะความเร็วอินเทอร์เน็ตอาจเป็นเพราะนั่นคือสิ่งเดียวที่ฉันสนใจจริงๆ ',
#  'หน้าจอแสดงสีที่ยอดเยี่ยม ',
#  'เหตุผลว่าทำไม ?เป็นเพราะเมื่อคุณซื้อมันคุณรู้สิ่งแรกที่คุณจะไม่สูญเสียมูลค่าสำหรับแล็ปท็อปนั้นราคาจะยังคงเหมือนเดิมในปีหน้าและแม้ว่า Apple จะตัดสินใจเปลี่ยนโหมดลดลง 10-20 % ซึ่งแตกต่างจากแล็ปท็อปพีซีซึ่งลดลงมากกว่า 80 % ',
#  'หน้าจอ 17 นิ้วมีขนาดใหญ่มาก แต่คอมพิวเตอร์มีน้ำหนักเบามาก ',
#  'ความคิดเห็นของฉันเกี่ยวกับ Sony ลดลงอย่างรวดเร็วเท่ากับตลาดหุ้นได้รับการสนับสนุนที่น่ากลัว แต่เครื่องนี้ทำให้เกิดการพุ่งอีกครั้ง ',
#  'เพื่อให้บลูทู ธ ทำงานได้อย่างถูกต้องคุณต้องติดตั้งตัวจัดการการเปิดตัวบนดีวีดีไดรเวอร์/แอปพลิเคชันหรือจะไม่แสดงหลังจากโหลดซ้ำ ',
#  'ฉันชอบหน้าจอแก้ว ',
#  'การ์ดกราฟิกแบบสลับได้ค่อนข้างหวานเมื่อคุณต้องการเล่นเกมบนแล็ปท็อป ',
#  'อายุการใช้งานแบตเตอรี่ยังไม่ลดลงตั้งแต่ฉันซื้อดังนั้นฉันจึงตื่นเต้นกับสิ่งนั้น ',
#  'เมื่อฉันเรียกว่าโตชิบาพวกเขาจะไม่ทำอะไรเลยและพยายามที่จะเรียกเก็บเงินฉัน $ 35 สำหรับการโทรศัพท์แม้ว่าพวกเขาจะไม่ได้รับการสนับสนุนทางเทคนิคใด ๆ ก็ตาม ',
#  'ฉันซื้อสมุดบันทึกนี้และมีเพียง 3 เดือนถ้ามันโอเวอร์โหลดพร้อมกับอัปเดต MGR Boot ',
#  'โอ้และถ้ามันไม่ดีพอมันไม่ได้มาพร้อมกับซีดีการกู้คืนดังนั้นคุณสามารถสร้างได้ถ้าคุณรู้วิธีหรือซื้อถ้าคุณซื้อมันราคาคือ $ 25 สำหรับซีดีสองแผ่น ',
#  'ราคาและคุณสมบัติมากกว่าตรงตามความต้องการของฉัน ',
#  'Skype ก็เท่ห์ด้วยเครื่องนี้ด้วย ',
#  'นอกจากนี้ HDD ยึดไว้ข้างในโดยใช้รางและมีเพียงชุดเดียวในฮาร์ดไดรฟ์หลัก ',
#  'ทั้งหมดที่ฉันจะบอกว่าตอนนี้คือมันมีราคาสูงกว่าสองราคาถูกกว่าและมีคุณภาพดีกว่าอึของฉัน Vaio ',
#  'เกมเป็นปัญหาหลัก ',
#  'พวกเขาบอกว่าสิ่งนี้จะทำให้การรับประกันของฮาร์ดไดรฟ์เป็นโมฆะ (ฉันไม่เข้าใจว่าทำไม แต่อย่างไรก็ตาม) ',
#  'คอมพิวเตอร์ที่ยอดเยี่ยมสำหรับการใช้งานบ้านเบา ๆ และการใช้ธุรกิจ ',
#  'ลองพิจารณาแอพ MS Office เป็นเวอร์ชั่นทดลองทั้งหมดหวังว่าคุณจะมีสำเนาของคุณเอง ',
#  'ถึงกระนั้นฉันก็ชอบเล่นเกมออนไลน์ดังนั้นมันจึงยอดเยี่ยมมากที่มีคุณสมบัติที่ฉันสามารถทำสองหน้าต่างได้ ',
#  'อายุการใช้งานแบตเตอรี่นั้นยาวนานอย่างน่าอัศจรรย์เวลา 7 ชั่วโมงและ 5 ชั่วโมงหากคุณใช้ ',
#  'น้ำหนักเบาอายุแบตเตอรี่ที่ยาวนานการเปลี่ยนจากพีซีที่ยอดเยี่ยม ',
#  'การสแกนไวรัสนอร์ตันเป็นเพียงช่วงเวลาสั้น ๆ ที่แตกต่างจากคนอื่น ๆ ที่มักจะดีเป็นเวลาหนึ่งปี ',
#  'ฉันเป็นผู้ซื้อ Mac เป็นครั้งแรกและประหลาดใจกับคุณสมบัติและใช้งานง่ายสำหรับข้อเสนอ Mac ',
#  'มาเต็มแล้ว - ดี ',
#  'ฉันสังเกตเห็นว่า Windows มีระบบใหม่ที่เรียกว่า Windows 7 แล้วผู้ใช้ Vista ของเราล่ะ?พวกเขาควรได้รับข้อบกพร่องทั้งหมดจาก Vista ก่อนที่จะลงทุนในระบบใหม่ ',
#  'สิ่งเดียวที่ฉันมีคือคีย์กว้างคือความมืดเล็กน้อยที่จะเห็นตัวอักษรจะช่วยได้ถ้ามันเบากว่าเล็กน้อย ',
#  'นี่คือสิ่งที่ตรงกันข้ามกับการออกแบบตามหลักสรีรศาสตร์ ',
#  'สิ่งเดียวที่ฉันไม่ชอบเกี่ยวกับ Mac ของฉันคือบางครั้งมีโปรแกรมที่ฉันต้องการให้สามารถทำงานได้และฉันไม่สามารถทำได้ ',
#  'ไร้สายไม่ได้เป็นปัญหาสำหรับฉันเช่นเดียวกับคนอื่น ๆ ที่ได้รับการรับรอง ',
#  'สมุดบันทึก MacBook ตายอย่างรวดเร็วเนื่องจากอายุการใช้งานแบตเตอรี่สั้น ๆ รวมถึงโปรแกรมพื้นหลังมากมายที่ทำงานโดยไม่มีความรู้ของผู้ใช้ ',
#  'ทุกสิ่งที่คุณสามารถทำได้ด้วยแทร็คแพดทำให้การสำรวจรอบคอมพิวเตอร์และโปรแกรมของมันง่ายขึ้นเร็วขึ้นและง่ายขึ้น ',
#  'ฉันเดาว่าสิ่งที่ดีเพียงอย่างเดียวที่ออกมาจากสิ่งเหล่านี้คือลำโพงและซับวูฟเฟอร์ ',
#  'มีกล้องในตัวพร้อมเอฟเฟกต์พิเศษ- สำหรับวิดีโอและการถ่ายภาพ ',
#  'ทั้งหมดนี้เป็นราคาที่ดี ',
#  'อีกสิ่งหนึ่งคือหลังจากนั้นเพียงหนึ่งเดือนคีย์เมาส์ซ้ายก็พังและมีค่าใช้จ่าย $ 175 เพื่อส่งไปเพื่อแก้ไข ',
#  'มันมีความเร็วที่ดีและพื้นที่ฮาร์ดไดรฟ์มากมาย ',
#  'แบตเตอรี่ที่มีอายุยืนยาวมาก (สูงสุด 10-11 ชั่วโมงขึ้นอยู่กับวิธีการตั้งค่าระดับพลังงาน) ',
#  'รุ่นสีดำยังมีลักษณะไร้รอยต่อที่ดีมาก - หนึ่งในสมุดบันทึกที่ดูดีกว่าที่ฉันเคยเห็น ',
#  'บริการด้านเทคนิคสำหรับเดลล์เป็นโลกที่ 3 ดังนั้นมันอาจไม่ได้กังวล ',
#  'กราฟิกแย่มากและการรับประกันไม่คุ้มค่ากับการชำระเงินราคาถูกบนคอมพิวเตอร์ ',
#  'พวกเขาทำให้ฉันลำบากอีกครั้ง แต่พวกเขาเป็นความผิดปกติในแบตเตอรี่เองมันไม่ตาย ',
#  'หากคุณไม่รู้สึกสบายใจที่จะทำด้วยตัวเองเพียงซื้อเคสและมีความสุขและดูดีฉันซื้อสีขาวจาก Best Buy ',
#  'ความเร็วที่ยอดเยี่ยมสำหรับการประมวลผลข้อมูล ',
#  'มันใช้ประโยชน์ได้ดีสำหรับการเงินการกำหนดเวลาค่าใช้จ่ายทางธุรกิจของพ่อแม่ของฉันและเป็นเรื่องที่น่าอัศจรรย์สำหรับการเล่นเกม ',
#  'ฉันได้รับการสอนให้ใช้ Photoshop และประหลาดใจ ',
#  'การอัปเดตไดรเวอร์ไม่สามารถแก้ไขปัญหาได้น่าผิดหวังมาก ',
#  'มันไม่ได้ผลคุ้ม ',
#  'มันทำงานได้ดีจริงๆ ',
#  'HD ที่ใหญ่กว่า, กราฟิกที่ดีกว่าและ HD BID ',
#  'กล้องในตัวนั้นมีประโยชน์มากเมื่อพูดคุยกับเทคโนโลยีอื่น ๆ ในอาคารห่างไกลในมหาวิทยาลัยของเรา ',
#  "เครื่องเขียนดีวีดีแตกหลังจากการเผาผลาญ 3 DVD 'd ในช่วงเวลานั้น! ",
#  'มันทำงานได้ดีกับไร้สายของเราและพวกเขาก็ไม่มีปัญหา ',
#  'การสนับสนุนผลิตภัณฑ์แย่มากเนื่องจากการโทรแต่ละครั้งทำให้ฉันเสียค่าใช้จ่ายทางไกล ',
#  'โดยรวมแล้วคอมพิวเตอร์ใช้งานง่ายมากหน้าจอนั้นสมบูรณ์แบบคอมพิวเตอร์ที่ยอดเยี่ยมลูกสาวของฉันชอบ ',
#  'ปลอกของสายไฟทอดและทำให้สามีของฉันตกใจเมื่อเขาดึงมันออกมาจากซ็อกเก็ต ',
#  'มันไม่ได้เก็บสัญญาณอินเทอร์เน็ตไม่ว่าคุณจะนำมาจากที่ใด ',
#  'เป็นผลิตภัณฑ์ที่ยอดเยี่ยมในราคาที่ดี! ',
#  'แต่ดู MacBook Pro นั้นแตกต่างกันเพราะอาจมีป้ายราคาขนาดใหญ่ แต่มาพร้อมกับซอฟต์แวร์เต็มรูปแบบที่คุณต้องการและส่วนใหญ่มีการอัปเดตในอนาคตฟรี ',
#  'และตัวแสดงหลายหน้า (ช่วยให้คุณสามารถกดปุ่มหนึ่งปุ่มเพื่อดูทุกหน้าแยกต่างหากที่เปิดในเวลาเดียวกันในหน้าจอเดียว) เหมาะสำหรับผู้ที่ทำงานไม่หยุดหรือเพียงแค่ซื้อสินค้าออนไลน์ ',
#  'แป้นพิมพ์ขนาดดีและใช้งานง่าย ',
#  'คุณสมบัติที่ยอดเยี่ยม ',
#  'ฉันดีใจที่มันมีคุณสมบัติที่ยอดเยี่ยมในนั้น ',
#  'เมื่อพิมพ์ตัวอักษรและช่องว่างมักจะถูกละเว้นให้ผู้ใช้ต้องทำซ้ำคำและประโยคมากมาย ',
#  'เพียงไม่กี่วันหลังจากที่ฉันได้รับคอมพิวเตอร์กลับมาหน้าจอแข็งอีกครั้ง ',
#  'มันไม่เหมาะสำหรับเด็กเพราะอุณหภูมิ ',
#  'แม้ว่าฉันจะเชื่อว่าระบบปฏิบัติการ Windows อาจเป็นข้อผิดพลาดสำหรับปัญหาบางอย่าง ',
#  'ระบบปฏิบัติการที่ยอดเยี่ยมการปรับปรุงที่ยอดเยี่ยมของสายที่มีอยู่กระแทกความเร็วของโปรเซสเซอร์และเพิ่มพอร์ตสายฟ้า ',
#  'ภาพกรอบและสะอาด ',
#  'แม้ว่า Windows Vista จะเปรียบเทียบกับ Windows XP ',
#  'คอมพิวเตอร์ทำงานได้อย่างรวดเร็วโดยไม่มีปัญหาและซอฟต์แวร์ Ilife ที่มาพร้อมกับมัน (iphoto, Imovie, iWeb, iTunes, GarageBand) ก็มีประโยชน์มากเช่นกัน ',
#  'ตอนแรกมันทำงานได้ดีเป็นเวลาหนึ่งเดือนหรือมากกว่านั้นคณะกรรมการระบบล้มเหลวและฉันส่งไปยังโตชิบาเรื่องร้องเรียนบางอย่างและอีกสามสัปดาห์ต่อมาฉันได้รับแล็ปท็อปของฉันกลับมาเพื่อค้นพบว่ามันยังมีปัญหาเดียวกันดังนั้นตอนนี้ฉันต้องส่งกลับมาอีกครั้งเพื่อให้ได้รับการแก้ไขอีกครั้ง ',
#  'จนกว่าฉันจะซื้อเดลล์ฉันคิดว่าคุณแค่มองหาสิ่งที่คุณต้องการ (ขนาด, ซอฟต์แวร์, ตัวเลือก, ฮาร์ดแวร์) และซื้อข้อเสนอที่ดีที่สุดที่คุณสามารถหาได้ ',
#  'มันมีหน่วยความจำมากมายฮาร์ดไดรฟ์จำนวนมากและกราฟิกที่ยอดเยี่ยม ',
#  'อย่างไรก็ตามแฟนของฉันตระหนักว่าบานพับของเน็ตบุ๊กนั้นค่อนข้างหลวม (เมื่อคุณเปิดหรือปิด LCD) ',
#  'ปัญหาของฉันคือการบริการลูกค้าของ Dell ',
#  'บริการ RMA ของ Newegg นั้นยอดเยี่ยมเช่นเคยฉันติดต่อพวกเขาดึกดื่นเมื่อคืนวันศุกร์และพวกเขาออกหมายเลข RMA ให้ฉันและฉลากการจัดส่งแบบเติมเงินล่วงหน้าในเช้าวันรุ่งขึ้น ',
#  'การออกแบบ: ทนทานมาก ',
#  'เป็นเรื่องง่ายที่จะเปลี่ยนจากแป้นพิมพ์หนึ่งไปยังอีกคีย์บอร์ด ',
#  'ปัญหาเดียวของฉันคือ: 1) ความละเอียดของหน้าจอ/วิดีโอไม่เพิ่มขึ้นเป็นความละเอียดที่สูงขึ้นจากนั้น 1024 x 60 ',
#  'มันค่อนข้างเร็วและไม่มีอาการสะอึกในขณะที่ฉันใช้มันสำหรับการท่องเว็บอัปโหลดรูปภาพดูภาพยนตร์ (720p) ในบางโอกาสและสร้างงานนำเสนอ ',
#  'จอแสดงผลคุณภาพฉันชอบ HP เป็นคอมพิวเตอร์/เครื่องพิมพ์เดียวที่เราจะซื้อ ',
#  'คุณสมบัติที่ยอดเยี่ยมสิ่งเดียวที่ต้องการคือลำโพงที่ดีกว่า ',
#  'ฉันซื้อแล็ปท็อปนี้และพบว่าแท็บไม่ทำงาน ',
#  '-เรียกว่าสำนักงานใหญ่อีกครั้งพวกเขารายงานว่าแผง TFT เสียควรได้รับการแก้ไขภายในสิ้นสัปดาห์ (สัปดาห์ที่ 3) ',
#  'การนำทางผ่านคอมพิวเตอร์นั้นยอดเยี่ยมมากเมื่อเทียบกับระบบปฏิบัติการ Windows เช่นกัน ',
#  'หน้าจอถูกล้อมกรอบครึ่งถึงขอบเต็มนิ้วที่ไม่จำเป็นอย่างเห็นได้ชัดลดขนาดหน้าจอและเพิ่มจำนวนมาก ',
#  'ฉันต้องติดตั้ง windows ใหม่ภายในสองสัปดาห์หลังจากการซื้อและค้นพบรอยแตกในบานพับหน้าจอ ',
#  'ปัญหาที่สองเกี่ยวข้องกับแบตเตอรี่ที่โฆษณาว่ามีอายุการเก็บรักษา 11 ชั่วโมง แต่เมื่อชาร์จเต็มแสดงให้เห็นเพียง 7 ชั่วโมงของการให้บริการ ',
#  'และที่เก็บข้อมูลมากมายพร้อม 250 GB (แม้ว่าฉันจะอัพเกรดสิ่งนี้และ RAM .. ) ',
#  'โปรแกรมจะผิดพลาดตลอดเวลาและมันก็กลายเป็นแล็ปท็อปที่ไม่แน่นอนและไม่น่าเชื่อถือสำหรับฉัน ',
#  'การผูกกุญแจใช้เวลาเล็กน้อยในการทำความคุ้นเคย แต่ได้รัก MacBook Pro ',
#  'แป้นพิมพ์มีขนาดที่สมเหตุสมผล ',
#  'เสียงพัดลม: พัดลมส่งเสียงฟู่อย่างต่อเนื่องในพื้นหลัง ',
#  'หน้าจอสว่างและชัดเจนระบบปฏิบัติการนั้นแข็งแกร่งและเป็นมิตรกับมือใหม่ ',
#  'มันมีโปรเซสเซอร์ที่เร็วขึ้น. 1 GHz และฮาร์ดไดรฟ์ 500GB หุ้น ',
#  '`` นี่ไม่ใช่เรื่องใหญ่ฉันไม่ได้สังเกตเห็นปัญหาเกี่ยวกับดีวีดีหรือสื่ออื่น ๆ ผ่านการส่งออก USB เท่านั้น ',
#  'ด้วยแล็ปท็อป Windows เมาส์ไร้สายจึงเป็นสิ่งที่ต้องทำอย่างแน่นอน ',
#  'คุณภาพดีมากและทำดี ',
#  'หลานสาวและหลานชายของฉันเล่นเกมเว็บสองสามเกมและมันทำงานทุกอย่างที่ไม่ต้องใช้การ์ดวิดีโอเฉพาะ ',
#  'มันมีทัชแพดขนาดเต็มที่มี 2 ปุ่มแทนที่จะเป็นเพียงปุ่มเดียว ',
#  'โดยทั่วไปเมื่อฉันซื้อแล็ปท็อปใหม่ฉันมักจะใช้เมาส์ภายนอกเพื่อความสะดวก ',
#  'มันง่ายมากที่จะตั้งค่าและง่ายมากที่จะคุ้นเคย ',
#  'สิ่งเดียวที่สามารถอัปเดตได้คือวิดีโอนอกเหนือจากที่คุณตั้งไว้ ',
#  'มันเป็นแล็ปท็อปที่ดีสำหรับคุณค่าของมัน ',
#  'จากนั้นฮาร์ดไดรฟ์ก็ล้มเหลว ',
#  'แน่นอนการรับประกันของฉันจะหมดในเดือนหน้า ',
#  'ฉันพบว่ามันง่ายมากที่จะเข้าถึงอินเทอร์เน็ตไร้สาย ',
#  'นี่เป็นสิ่งที่คุ้มค่ามากสำหรับเงิน ',
#  'แบตเตอรี่ไม่เคยทำงานได้ดี ',
#  'ฉันจะไม่ซื้อคอมพิวเตอร์เครื่องอื่นจากเดลล์อีกเลยว่ามันทำงานได้อย่างน่ากลัวและวิธีการปฏิบัติของ บริษัท ',
#  'มีขนาดเล็กพอที่จะใช้ในเที่ยวบินที่ยาวนานเบาพอที่จะผ่านสนามบินและทรงพลังพอที่จะแทนที่เดสก์ท็อปของฉันในขณะที่เดินทางไปธุรกิจนาน ',
#  'การพิมพ์บนคีย์บอร์ดจะอึดอัดหลังจากใช้งานเพิ่มเติมเนื่องจากขอบคมที่ข้อมือของคุณพัก ',
#  'มันมีโปรแกรมที่ยอดเยี่ยมมากมายเช่น Ilife, Iphotos และอื่น ๆ ',
#  'ฉันขอแนะนำแล็ปท็อปนี้ให้กับทุกคนที่ต้องการการแสดงที่ยอดเยี่ยมจากแล็ปท็อปและต้องการผ่อนคลายและไม่ได้รับการสาปแช่งพระเจ้ากำลังจะโยนแล็ปท็อปของคุณออกไปนอกประตู ',
#  'ความละเอียดของหน้าจอเป็นสิ่งที่ฉันกำลังมองหา ',
#  'แม้ว่ามันจะใช้เสือดาวหิมะ แต่ 2.4 GHz C2D เป็นซีพียูโบราณและล้อหมุนเป็นครั้งคราวจะปรากฏขึ้นเมื่อใช้งานแอปพลิเคชัน MAC ในสำนักงานเช่น Word หรือ Excel ',
#  'ไม่มีแผ่นตัวเลขทางด้านขวาของแป้นพิมพ์ซึ่งเป็นคนเกียจคร้าน ',
#  'หากการอัพเกรดเป็นไปได้ที่ Windows 7 เต็มฉันจะเป็นคนที่มีความสุขมาก ',
#  'ตอนแรกฉันกังวลว่าฉันไม่สามารถดูงานที่ฉันได้ทำในวิทยาลัยใน MAC ของฉันเนื่องจากการจัดรูปแบบพีซี แต่ฉันรู้สึกตื่นเต้นมากขึ้นที่จะได้เรียนรู้โปรแกรมเช่น Ilife และ Iwork ที่อนุญาตให้คุณแปลงเอกสารพีซีของคุณให้อ่านได้ไฟล์บน Macs ',
#  'ทำงานเร็วและแป้นพิมพ์เลย์เอาต์ปกติดีกว่ามาก ',
#  'โปรแกรมทั้งหมดนั้นง่ายและตรงไปตรงมาใน MacBook Pro ของฉันมันสะอาดและเป็นระเบียบซึ่งฉันพยายามเป็นตัวของตัวเองเสมอ ',
#  'ผู้เริ่มต้น Windows 7 นั้นยอดเยี่ยม (ไม่คุณไม่ได้เปลี่ยนพื้นหลัง) แต่ฉันไม่จำเป็นต้องใช้ฉันใช้มันเพื่อทำงานในโรงเรียน ',
#  'การสนับสนุนนั้นขาดความดแจ่มใสและตอนนี้ฉันแค่ต้องการเงินคืน ',
#  '``> iPhoto น่าจะเป็นโปรแกรมที่ดีที่สุดที่ฉันเคยร่วมงานด้วย: ง่ายและสะดวก ',
#  'ฉันชอบที่จะเขียนและเล่นกับกราฟิกและการเขียนโปรแกรม HTML และโตชิบาใหม่ของฉันใช้งานได้ดีทั้งคู่! ',
#  'แล็ปท็อปของฉันตอนนี้ไม่มีแบตเตอรี่ ',
#  'มันทำให้คอมพิวเตอร์ใช้งานง่ายขึ้นและนำทางมาก ',
#  'ต้องการแบตเตอรี่ที่ยั่งยืนนานกว่า 1 ถึง 2 ชั่วโมง ',
#  'ในเดือนพฤษภาคมฉันเริ่มมีปัญหากับพอร์ต USB ที่ไม่ทำงาน ',
#  'Microsoft Office เวอร์ชัน MAC นั้นถูกกว่าการซื้อจริงและใช้งานได้เช่นกัน ',
#  'Toshiba Net Book ทำงานได้ดีมาก ',
#  'ทัชแพดนั้นดี - อีกครั้งมันเป็นทัชแพดจริง ',
#  'รูปภาพมีความชัดเจนเท่าที่จะทำได้ ',
#  'นอกจากนี้ยังมีน้ำหนักเบามากทำให้การขนส่งคอมพิวเตอร์นี้ง่ายมาก ',
#  'มันยอดเยี่ยมสำหรับการเล่นเกมคอมพิวเตอร์ ',
#  'ข้อบกพร่องคือคอมพิวเตอร์เครื่องนี้ไม่ได้มีไว้สำหรับนักเล่นเกมคอมพิวเตอร์เนื่องจาก OS X ',
#  'พวกเขามีบริการซ่อมแซมที่เลวร้ายที่สุดของโลก ',
#  'ฉันยังสามารถติดตั้งและใช้โปรแกรม photoshop และ pasteffects ได้อย่างง่ายดาย ',
#  'มันสมบูรณ์แบบสำหรับทุกสิ่งและทำงานได้เร็วกว่าพีซีทั่วไป! ',
#  'จากนั้นหลังจากจ่ายเงินให้ตรวจสอบฉันได้รับการบอกว่ามันเป็นปัญหาเดียวกันที่อ้างถึงในเว็บไซต์ แต่ฉันต้องจ่ายเงินต่อไปเพราะมันเป็นสงครามที่ผ่านมา ',
#  'ฉันติดอยู่กับรูปลักษณ์และความน่าเชื่อถือที่แล็ปท็อปนี้แสดงไว้แล้ว ',
#  'และการต้องจัดการกับ บริษัท เป็นฝันร้ายที่เลวร้ายยิ่งกว่าเดิม ',
#  'มันมีคุณสมบัติทั้งหมดที่จำเป็นสำหรับวิทยาลัยและหากไม่สามารถเพิ่มลงในคอมพิวเตอร์ได้ ',
#  'ฉันเป็นเจ้าของแล็ปท็อปเครื่องนี้น้อยกว่าสองเดือนแล้วปุ่มเมาส์ก็พังแล้ว ',
#  'มันค่อนข้างดีนอกเหนือจากประสิทธิภาพที่ไม่ดีความร้อนสูงเกินไปและหน้าจอสีน้ำเงินเป็นครั้งคราว ',
#  'พื้นที่พิเศษมากมาย แต่แป้นพิมพ์มีขนาดเล็กอย่างน่าขัน ',
#  'มันแย่มากที่ฉันคิดว่าฉันมีแบตเตอรี่เพียงครึ่งเดียวหรืออะไรบางอย่าง ',
#  'แป้นพิมพ์ที่ดีอายุการใช้งานแบตเตอรี่ที่ยาวนานฮาร์ดไดรฟ์ที่ใหญ่ที่สุดและ Windows 7 ',
#  'โปรเซสเซอร์นั้นรวดเร็วและมีประสิทธิภาพมากเมื่อฉันโหลดหน้าเว็บและแอปพลิเคชัน ',
#  'แบตเตอรี่ของฉันไม่ดีประมาณหนึ่งปีครึ่งหลังจากมีมันและมีราคาประมาณแปดสิบถึงหนึ่งร้อยดอลลาร์! ',
#  'มันทำทุกอย่างที่เราต้องการและดูดีในการบูต ',
#  'ในฐานะผู้ใช้ Windows ตลอดชีวิตฉันยินดีเป็นอย่างยิ่งที่ได้เปลี่ยนแปลง Mac ',
#  'MacBook นั้นดีขึ้นคอมพิวเตอร์ของฉันไม่เคยมีไวรัสและแล็ปท็อปทำงานเร็วพอ ๆ กับวันแรกที่ฉันซื้อ ',
#  'ฉันเช็ดเกือบทุกอย่างออกจากมันติดตั้ง OpenOffice และ Firefox และฉันกำลังใช้งานเครื่องที่มีประสิทธิภาพและมีประโยชน์อย่างไม่น่าเชื่อในราคาที่ดี ',
#  'โดยรวมแล้วฉันรู้สึกว่าเน็ตบุ๊กนี้มีคุณภาพไม่ดีมีประสิทธิภาพที่ไม่ดีแม้ว่ามันจะมีอายุการใช้งานแบตเตอรี่ที่ยอดเยี่ยมเมื่อมันทำงาน ',
#  'ฉันเลือกมันออกมาเพราะราคาไม่แพง ($ 400) และฉันคิดว่ามันจะเป็นแล็ปท็อปเครื่องแรกที่ใช้งานง่าย ',
#  'ปัญหาเดียวของฉันคือฉันไม่สามารถ regคีย์ผลิตภัณฑ์ ',
#  'แน่นอนว่ามันมีปุ่ม Touch One แต่นั่นเป็นคุณสมบัติที่ดีที่สุดของคอมพิวเตอร์ ',
#  'อายุการใช้งานแบตเตอรี่ที่ยอดเยี่ยม ',
#  'ในตอนแรกคอมพิวเตอร์ดูเหมือนจะเป็นข้อตกลงที่ยอดเยี่ยม-รายละเอียดระดับสูงในราคาต่ำและต่ำ ',
#  'รักความเสถียรของซอฟต์แวร์ Mac และระบบปฏิบัติการ ',
#  'นอกจากนี้ยังมีความสามารถในการแก้ไขวิดีโอปานกลาง (แม้ว่าคุณอาจต้องการประสิทธิภาพการทำงานของ MacBook Pros ขนาดใหญ่สำหรับการแก้ไขวิดีโอมือถือหนัก) ',
#  'มันมีโปรเซสเซอร์ที่เร็วขึ้นและ RAM มากขึ้น ',
#  'ต้องการคุณลักษณะที่ทันสมัยและทันสมัยมากขึ้น ',
#  'แป้นพิมพ์นั้นยอดเยี่ยม แต่ปุ่มควบคุมหลักและรองอาจมีความทนทานมากขึ้น ',
#  'ฉันได้รับมันกลับมาอีกครั้งและบอกว่าเมนบอร์ดถูกแทนที่ดังนั้นตอนนี้ฉันอยู่ในเมนบอร์ดที่สองภายใน 3 เดือน ',
#  'รักความเร็วโดยเฉพาะ! ',
#  'ไม่เพียง แต่เวอร์ชันของโปรแกรมเหล่านี้ที่สามารถบันทึกได้ทำงานและเปิดทั้งพีซีและ Mac รุ่นของโปรแกรมเหล่านี้บน Mac นั้นดีกว่ากราฟิกและใช้งานได้ดีกว่า ',
#  'ความเร็วช่วยให้คุณมีพลังในการทำงานในโครงการเหล่านี้ได้อย่างราบรื่นและหลายครั้งในแต่ละครั้งถ้าคุณหว่าน ',
#  'แล็ปท็อปที่ยอดเยี่ยมและขนาดที่สมบูรณ์แบบในการพกพาในวิทยาลัย ',
#  'ปัญหาที่แท้จริงของฉันกับมัน?คำแถลงเกี่ยวกับอายุการใช้งานแบตเตอรี่ 7 ชั่วโมงไม่ได้เป็นเพียงแค่การพูดเกินจริง - มันเป็นเรื่องโกหก ',
#  'อายุการใช้งานแบตเตอรี่ก็ค่อนข้างดี ',
#  'ฉันพบว่ามันใช้งานง่ายมากให้ข้อมูลการแจ้งเตือนและบทช่วยสอนทำให้ง่ายมากสำหรับคนอย่างฉันที่ไม่ได้ก้าวหน้าทางเทคโนโลยีอย่างแน่นอนในการเรียนรู้ที่จะใช้คุณสมบัติและโปรแกรมต่าง ๆ ',
#  'ฉันไม่มีหน้าต่างป๊อปอัพโง่ ๆ (แม้ว่าฉันจะถูกบล็อกป๊อปอัป) ฉันไม่ต้องรอ 5 นาทีเพื่อดาวน์โหลดเว็บเพจและที่ดีที่สุดของทั้งหมดที่ฉันสามารถเรียกใช้ซอฟต์แวร์การเขียนโปรแกรมเว็บทั้งหมดที่ฉันต้องการเพื่อใช้ทั้งหมดในครั้งเดียวโดยไม่ทำให้ฉันช้าลง ',
#  'หน่วยความจำสามารถอัพเกรดได้ ',
#  'การเข้าถึงเว็บผ่านเครือข่าย 3G นั้นช้ามากมันน่าผิดหวังและน่าผิดหวังมาก ',
#  'หน้าจอขนาดใหญ่ยังช่วยได้เมื่อคุณทำงานในโปรแกรมการออกแบบเช่น Adobe Creative Suite ',
#  'นี่เป็นเดลล์แรกของฉันที่ฉันได้ยินว่าการบริการลูกค้าของพวกเขาขาดและพวกเขากำลังทำงานเพื่อปรับปรุงมัน! ',
#  'เช่นเดียวกับการมีปลั๊กในคอมพิวเตอร์หลวม ',
#  'ฝาครอบ HDD ที่สองมีผนังด้านในนั้นจะต้องหักถ้าคุณติดตั้งอะไร ',
#  'ผลิตภัณฑ์ที่ยอดเยี่ยมโดย Apple ด้วยการออกแบบที่ดูดีใหม่ ',
#  'ฉันชอบแป้นพิมพ์ ',
#  'ฉันใช้ iPhoto ตลอดเวลาซึ่งเป็นโปรแกรมที่ยอดเยี่ยมสำหรับทุกคนที่เข้าสู่การถ่ายภาพ - มือสมัครเล่นและผู้เชี่ยวชาญเหมือนกัน ',
#  'ตอนนี้ง่ายอย่างที่ใช้และฉันคิดว่ามันเป็นแล็ปท็อปเริ่มต้นที่ยอดเยี่ยม ',
#  'นับตั้งแต่ฉันซื้อแล็ปท็อปนี้จนถึงตอนนี้ฉันยังไม่ได้สัมผัสอะไรเลย ',
#  'นอกจากนี้แถบอวกาศทำให้คลิกที่มีเสียงดังทุกครั้งที่คุณใช้ ',
#  'Iphotos เป็นโปรแกรมที่ยอดเยี่ยมสำหรับการจัดเก็บและจัดระเบียบภาพถ่าย ',
#  'นอกเหนือจากนั้นมันเป็นเครื่องที่มีประสิทธิภาพที่ยอดเยี่ยมและตอบสนองความต้องการทั้งหมดของฉันและอื่น ๆ ',
#  'โปรแกรมนี้ยอดเยี่ยมเช่น iPhoto (รักความสามารถในการแก้ไข), imail (ซึ่งสามารถรวมเข้ากับสมุดที่อยู่บน iPod และ iPad), iMovie ฯลฯ ',
#  'สะดวกในการใช้งานง่ายต่อการขนส่ง ',
#  'ตัวคอมพิวเตอร์เองเป็นผลิตภัณฑ์ที่ดี แต่สถานีซ่อมแซมจะมีกลิ่นเหม็น ',
#  'ฉันคิดว่าราคานั้นยอดเยี่ยมสำหรับรายละเอียด ',
#  'สิ่งเดียวที่ตกต่ำคือมันไม่มีไดรฟ์ซีดี แต่ฉันพบว่าพวกเขาราคาถูกมากและยังพกพามากทำให้เป็นเพื่อนที่ดีที่สุดสำหรับคนที่มักจะมองหาพื้นที่มากขึ้น ',
#  'ดังนั้นความจุฮาร์ดดิสก์ไม่สำคัญสำหรับฉัน ',
#  'ฉันชอบที่คุณสามารถเลื่อนลงในหน้าต่างโดยใช้สองนิ้วบนแทร็กแพด ',
#  'ทุกอย่างตั้งแต่การออกแบบไปจนถึงระบบปฏิบัติการนั้นง่ายและตรงประเด็น ',
#  'โดยส่วนตัวแล้วฉันชอบรูปลักษณ์การเล่นเกม แต่ต้องการเครื่องจักรที่ส่งมอบประสิทธิภาพการเล่นเกมในขณะที่ยังคงดูเป็นมืออาชีพต่อหน้าลูกค้าของฉัน ',
#  'นี่เป็นเพียงการเปลี่ยนฮาร์ดไดรฟ์ของมัน! ',
#  'เมื่อคุณดูข้อมูลจำเพาะของผลิตภัณฑ์ Apple เมื่อเทียบกับ Dell หรือ HP ใช่พวกเขาดูเหมือนจะให้น้อยลงสำหรับค่าใช้จ่ายที่สูงขึ้น ',
#  'ความหายนะเพียงอย่างเดียวคือการควบคุมระดับเสียง ',
#  'บูตเร็วมากและปิดตัวลง ',
#  'ในที่สุดฉันก็ตัดสินใจใช้แล็ปท็อปนี้เพราะมันเป็นราคาที่เหมาะสมสำหรับสิ่งที่ฉันต้องการ ',
#  'หากการเชื่อมต่ออินเทอร์เน็ตเป็นสิ่งสำคัญฉันขอแนะนำให้ไปกับ Dell Net Book สำหรับ 50 bucks เพิ่มเติมหรือซื้อการ์ดไร้สาย USB ',
#  'ฉันได้อ่านออนไลน์ว่าผู้ใช้บางคนมีปัญหาเสียง ',
#  'มันปล่อยเร็วเกินไป ',
#  'แต่พูดตามตรงปัญหาความเข้ากันได้และนิสัยใจคอเล็ก ๆ น้อย ๆ อื่น ๆ ทำให้ฉันคิดว่าฉันจะซื้อพีซีในครั้งต่อไป ',
#  'จากนั้นมันก็หยุดการชาร์จเลย ',
#  'ฉันไม่ได้สัมผัสกับความร้อนที่เกิดขึ้นมากมาย แต่ฉันขอแนะนำให้ซื้อขาตั้งอย่างไรก็ตามเนื่องจากลักษณะของการออกแบบ MacBook เนื่องจากเป็นอ่างล้างจานที่มีขนาดใหญ่มาก ',
#  'เว็บแคมค่อนข้างล้าหลังไม่ใช่สิ่งที่ยิ่งใหญ่ที่สุด ',
#  'ฉันไม่มีปัญหาที่สำคัญใด ๆ กับแล็ปท็อปยกเว้นว่าชิ้นส่วนพลาสติกที่ครอบคลุมสายพอร์ต USB ทั้งหมดออกมา ',
#  'การออกแบบเคสที่ทันสมัยที่ยอดเยี่ยมอยู่ด้านนอกเท่านั้น ',
#  'มันรวดเร็วเมื่อเชื่อมต่อแบบไร้สายกับเครือข่ายใด ๆ โดยไม่คำนึงว่าการเชื่อมต่อจะอ่อนแอหรือไม่ ',
#  'ราคามีการแข่งขันสูง ',
#  'คอมพิวเตอร์เครื่องนี้บางเป็นพิเศษสำหรับขนาดหน้าจอและกำลังการประมวลผล ',
#  'บางทีนี่อาจจะเกี่ยวข้องกับไวรัส แต่อาจไม่ได้ แต่คอมพิวเตอร์ได้ล็อคมาหลายครั้งและสองครั้งหน้าจอก็กลายเป็นสีดำ ',
#  'หน้าจอสว่างและสดใสและแป้นพิมพ์ใช้งานง่ายมากสำคัญมากสำหรับการใช้เครื่องพิมพ์ดีดด่วน ',
#  'ฉันมี iWorks, iTunes, อีเมล, MS Office, เครือข่ายและเครื่องพิมพ์ที่ตั้งค่าและทำงานได้อย่างสมบูรณ์ภายในหนึ่งชั่วโมง ',
#  'MacBooks มีขนาดเล็กพอที่จะพกพาได้มาก แต่เก็บข้อมูลและประสิทธิภาพมากมาย ',
#  'ความหายนะเพียงอย่างเดียวคือซอฟต์แวร์จำนวนมากที่ฉันไม่ได้ทำงานกับ Mac และ Iwork ไม่คุ้มกับราคาของมัน ',
#  'Mousepad เป็นความเจ็บปวดอย่างมากในตูด! ',
#  'ตั้งแต่นั้นมาฉันมีปัญหาเล็กน้อยเกี่ยวกับการทำงานที่ช้า ',
#  'การลงทะเบียน/การใช้งานครั้งที่ 1 เป็นเรื่องง่าย ',
#  'ใช้เวลาของคุณและผ่านการสอนอย่างอดทน ',
#  'แป้นพิมพ์สามารถใช้การตัดแต่งได้ ',
#  'แล็ปท็อปที่ส่งคืนสำหรับการซ่อมแซมครั้งที่ 2 และกลับมาพร้อมกับความเสียหายทางกายภาพที่ชัดเจน (แป้นพิมพ์โป่งและกริลล์ลำโพงกดลง) ปุ่มไม่ทำงานและพอร์ต USB ไม่ทำงาน ',
#  'จดหมายหยุดทำงานหลังจากสัปดาห์แรก ',
#  'ด้วยสิ่งที่ฉันรู้วิธีการทำคอมพิวเตอร์ทำงานได้สวยงาม ',
#  'ทุกอย่างดีกับเครื่องนี้: ความเร็วความจุสร้าง ',
#  'ฉันใช้สิ่งนี้สำหรับธุรกิจการสอนของฉันและเนื่องจากฉันมักจะตีกลับจากนักเรียนสู่นักเรียนมันเหมาะสำหรับการพกพาและอายุการใช้งานแบตเตอรี่ (ใช่มันได้รับ 8 ชั่วโมงตามที่โฆษณา!) ',
#  'มันอยู่ในสภาพที่ดีที่สุดและมีคุณภาพสูงมาก ',
#  'เมื่อถึงเวลาสำหรับบริการรับประกันถึงโตชิบาคุณไม่สำคัญ ',
#  'อย่างไรก็ตามหน้าจอน้ำแข็งยังคงเกิดขึ้น ',
#  "มันสั้นในอวกาศและการดาวน์โหลดมักจะมีปัญหาที่เสร็จสมบูรณ์หรือถูกกล่าวว่า 'เสียหาย' ",
#  '3) ฝ่ายสนับสนุนลูกค้าที่น่ากลัว ',
#  'Apple นั้นยอดเยี่ยมเกี่ยวกับความสวยงามของสิ่งต่าง ๆ พวกเขามักจะคิดผลิตภัณฑ์ที่ดูดีอยู่เสมอ ',
#  'ทำงานได้อย่างราบรื่นและรวดเร็ว ',
#  'ข้อเสียของเน็ตบุ๊กนี้ค่อนข้างเหมือนกันสำหรับเน็ตบุ๊กใด ๆ : ขนาดหน้าจอไม่ใช่สิ่งที่ฉันจ้องมองตลอดอายุการใช้งานแบตเตอรี่ 10-11 ชั่วโมงห้าวันต่อสัปดาห์ ',
#  'กราฟิกยอดเยี่ยมมาก ',
#  'ใน 5 เดือนคุณภาพการเชื่อมต่อแย่ลงเรื่อย ๆ ',
#  'หน้าจอขนาดใหญ่ช่วยให้คุณเพลิดเพลินไปกับการดูภาพยนตร์รูปภาพและ ฯลฯ ! ',
#  'หูฟังและแจ็คไมค์อยู่ด้านหน้าของ Touch-Pad ทำให้ Touch-Pad ใช้งานได้ยากเมื่อใช้หูฟัง/ไมค์ไม่ต้องพูดถึงแล็ปท็อปที่ออกแบบมาสำหรับคนถนัดขวา ',
#  'สำหรับราคา [$] (ข้อเสนอพิเศษ) นี่คือแล็ปท็อปที่ยอดเยี่ยม ',
#  'สิ่งที่ฉันชอบคือแล็ปท็อปทำงานได้ดีโดยไม่ต้องซื้อหน่วยความจำเพิ่มเติม ',
#  'มันกำลังบูตเร็วปิดและเชื่อมต่อกับอินเทอร์เน็ต ',
#  'นี่ไม่ใช่แล็ปท็อปเกมที่จริงจังหรือเครื่องสื่อที่จริงจัง ',
#  'พวกเขาแทนที่ฮาร์ดไดรฟ์ของฉันเช่นเดียวกับบอร์ดแม่ของฉัน ',
#  'ไม่มีอะไรจะบ่นเกี่ยวกับระบบ ',
#  'และมันมาพร้อมกับ OSX ใหม่ที่มาพร้อมกับคุณสมบัติใหม่ที่ทำให้การใช้งานง่ายขึ้น ',
#  'ตอนนี้หน้าจอเข้มขึ้นมืดลงมืดกว่า ',
#  'ฉันพาไปทุกที่กับฉันเพราะมันง่ายต่อการพกพา ',
#  'โอ้และมันมีคำและสิ่งของ แต่มันเป็นการทดลองใช้ดังนั้นหลังจากนั้นประมาณหนึ่งเดือนหรือมากกว่านั้นเมื่อคุณไปเปิดมันจะขอคีย์ผลิตภัณฑ์ที่ไม่ได้มาพร้อมกับคอมพิวเตอร์และแม้กระทั่งหลังจากคลิกยกเลิกมันจะไม่ปล่อยให้คุณใช้เลยฉันใช้เครื่องประมวลผลคำเก่าที่ใช้งานได้ดี ',
#  'แป้นพิมพ์มีความรู้สึกธรรมชาติที่ยอดเยี่ยม ',
#  'แบตเตอรี่ไม่นาน แต่ฉันแน่ใจว่าแบตเตอรี่อัพเกรดจะแก้ปัญหานั้นได้ ',
#  'ฉันมองอย่างใกล้ชิดกับรายละเอียดประสิทธิภาพอื่น ๆ และในขณะที่เปรียบเทียบฉันก็รับมันเพื่อให้ได้คุณสมบัติเหล่านี้เป็นมาตรฐาน ',
#  'ฉันซื้อเมื่อสัปดาห์ที่แล้วและในวันถัดไปก็ต้องกลับมาเพราะมันร้อนเกินความร้อนและหนูสัมผัสหยุดตอบสนอง ',
#  'หน้าปกของ DVD Drive ก็ออกมาเช่นกัน - เครื่องหมายของคุณภาพการก่อสร้างที่ไม่ดี ',
#  'แต่แขนเวลโครถูกฉีกขาดหลังจากใช้เพียงครั้งเดียว ',
#  'ซอฟต์แวร์นั้นยอดเยี่ยมมาก ',
#  "เราพกเน็ตบุ๊กที่นี่และที่นั่นดังนั้นจึงเป็นเรื่องน่ารำคาญเมื่อ LCD เพียงแค่ `` เลื่อน '' ลงไปด้านล่าง ",
#  'RAM 2 GB นั้นมีมากมายสามารถเรียกใช้ Windows 7 และอย่างน้อย 2 หรือ 2 โปรแกรมอื่น ๆ โดยไม่มีการชะลอตัวลง ',
#  'อายุการใช้งานแบตเตอรี่นั้นยอดเยี่ยมความเก่งกาจนั้นโดดเด่น ',
#  'Vista เป็นฝันร้าย ',
#  'โปรแกรมมาพร้อมกับคอมพิวเตอร์และทำงานได้อย่างสวยงาม ',
#  'ฉันรักเน็ตบุ๊กนี้เพราะมันมีหน้าจอและจอแสดงผลที่น่าทึ่งและมีขนาดเล็กและเบา แต่หลังจาก 1 สัปดาห์มันก็หยุดเปิดหน้าเว็บสำหรับฉัน (แม้หลังจากติดตั้งเบราว์เซอร์ใหม่) จากนั้นในที่สุดมันก็เริ่มให้หน้าจอสีน้ำเงินและพังทุกครั้งฉันบูตมัน ',
#  'แล็ปท็อปที่เรียกว่าช้าและฉันเกลียดมัน! ',
#  'เครื่องชาร์จดูเหมือนจะใหญ่สำหรับคอมพิวเตอร์ระดับนี้ ',
#  'ฉันไม่ชอบคุณภาพและตำแหน่งของลำโพง ',
#  'กราฟิกหน้าจอและความคมชัดและความคมชัดนั้นยอดเยี่ยมมาก ',
#  'ดังนั้นฉันจึงเรียกฝ่ายสนับสนุนลูกค้า (ซึ่งดีเกินไป) และพวกเขาก็ผ่านมันไปและมันก็เป็นเพียงคุณสมบัติด้านความปลอดภัยและมันก็ไม่ส่งผลกระทบต่อประสิทธิภาพเลยฉันแค่เลือกที่จะซ่อนข้อความ ',
#  'การออกแบบ unibody มีความหงุดหงิดและทนทาน ',
#  'หยุดการบูตน้อยกว่าหนึ่งสัปดาห์หลังจากการรับประกันหนึ่งปีของฉันเพิ่มขึ้น ',
#  'แต่สำหรับค่าใช้จ่ายนี้เป็นผู้ชนะ ',
#  'นอกจากนี้แบตเตอรี่ไม่นานนัก ',
#  "ฉันซื้อมาจาก HSN เพราะมันเป็น `` รวม '' ด้วยซอฟต์แวร์พิเศษ แต่เมื่อปรากฎว่าซอฟต์แวร์นั้นขัดมันบ่อยขึ้น ... .. ",
#  'ฉันต้องส่งแล็ปท็อปของฉันไปหาบริการทุก 3 เดือนและดูเหมือนว่าจะเป็นปัญหาเดียวกันกับที่พวกเขาบอกว่าพวกเขาได้แก้ไขแล้ว ',
#  'ประสิทธิภาพที่แข็งแกร่งในอุปกรณ์นี้ใช้ประโยชน์จากความสนุกและความรู้สึกที่แข็งแกร่งของยุคของความเร็วอุปกรณ์นี้ให้บริการความต้องการที่ทันสมัยทั้งหมดเป็นเกมที่แข็งแกร่งมากและมีประโยชน์มากสำหรับนักออกแบบ ',
#  'ฉันรู้สึกผิดหวังอย่างมากที่ค้นพบว่า HP (สิ่งที่ฉันคิดว่าเป็น บริษัท ที่มีชื่อเสียง) จะไม่ให้เกียรติการรับประกันเมื่อแฟนใบมีดแตกสลาย ',
#  'ในขณะที่คนส่วนใหญ่บอกว่าพีซีมีฟังก์ชั่นและความคุ้มค่าและ MAC นั้นค่อนข้างจะดูฉันคิดว่ามีบางสิ่งที่จะพูดเกี่ยวกับความเรียบง่ายของ Macs ',
#  'MacBook ของฉันดูดีขึ้นและผอมมาก! ',
#  'แบตเตอรี่ร้อนมากมันน่ากลัว ',
#  'มันดีมากที่ได้ดูและปุ่มง่ายต่อการพิมพ์ด้วย ',
#  'มันน่ากลัวอย่างยิ่งที่จะใช้แม้จะมีคุณสมบัติขั้นสูงที่เรียกว่าทั้งหมด ',
#  'ฉันต้องเปลี่ยนมันต่อไปจนกว่าจะตัดสินใจที่จะลดลงและไม่มีใบ้ ',
#  'มันยังคงสวยงามและมีการทำซ้ำสีที่ดีกว่าที่ฉันคาดไว้จากสมุดบันทึก ',
#  'เขารักมันและใช้งานง่ายและโรงเรียนเริ่มสอนเด็ก ๆ เกี่ยวกับคอมพิวเตอร์ก่อนดังนั้นมันจึงเป็นเรื่องง่ายสำหรับเขาที่จะเริ่มต้น ',
#  'นอกจากนี้ MacBooks ยังมาพร้อมกับคุณสมบัติอื่น ๆ อีกมากมายซึ่งเจ๋งมาก! ',
#  'การได้รับแผนการดูแล Apple เป็นสิ่งจำเป็น ',
#  'โดยรวมแล้วฉันอยากจะแนะนำสิ่งนี้ให้กับทุกคนและบอกพวกเขาว่าหากพวกเขาต้องการเผาเพลงหรือเล่นวิดีโอเกมเพื่อซื้อไดรฟ์ซีดี ',
#  'DV4 มีโปรเซสเซอร์ที่เร็วขึ้นหน่วยความจำมากขึ้นและฮาร์ดไดรฟ์ที่ใหญ่กว่าคอมพิวเตอร์เครื่องเก่าของฉันรวมถึงเว็บแคมคุณภาพดีกว่าหน้าจอที่ดีกว่าและคุณสมบัติอื่น ๆ อีกมากมาย ',
#  'ความหายนะเพียงอย่างเดียวคือแบตเตอรี่เพียง 1.5-2.0 ชั่วโมงเมื่อไม่เสียบเข้า ',
#  'กราฟิกในคอมพิวเตอร์เครื่องนี้ยังเป็นตัวเอก - ชัดเจนและสดใสมาก ',
#  'นอกเหนือจากซอฟต์แวร์ทดลองใช้และอายุการใช้งานแบตเตอรี่สั้น ๆ การขาดเว็บแคมมันยอดเยี่ยมมาก ',
#  'แป้นพิมพ์สีดำใหม่ใช้เวลาเล็กน้อยจากสีเทาก่อนหน้านี้ซึ่งดูป่วยจริง ๆ แต่มันก็ยังเป็นสมุดบันทึกที่ยอดเยี่ยม! ',
#  'ความน่าเชื่อถือของชิ้นส่วน Sony และคุณภาพของการบริการเป็นสิ่งที่เลวร้ายที่สุด ',
#  'เช่นเดียวกับแล็ปท็อปใด ๆ ที่ไม่ได้ซื้อด้วยตัวเลือกซอฟต์แวร์มันมาพร้อมกับสิ่งที่ฉันพิจารณาแอปพลิเคชันที่ไร้ประโยชน์ ',
#  'สำนักงานที่เข้ากันได้ แต่คุณสมบัติและการทำงานของมันเป็นสิ่งใหม่อีกครั้งดังนั้นคุณอาจประหยัดเงินและเรียนรู้โปรแกรม MAC ที่ติดตั้งไว้ล่วงหน้า ',
#  'มันใช้งานได้อย่างไร้ที่ติ! ',
#  'ฉันมีแล็ปท็อปกลับมาไม่ได้รับการซ่อมแซมตั้งแต่จ่าย $ 176 ทุก ๆ 3 เดือนเพียงแค่ไม่คุ้มค่า (นั่นคือระยะเวลาที่พอร์ตดูเหมือนจะคงอยู่) ',
#  'นอกจากนี้แบตเตอรี่จะถูกยิงอย่างสมบูรณ์ ',
#  '/ ระบบทำความเย็นที่ยอดเยี่ยม / การ์ดกราฟิกที่ดีกว่ามาก (ATI 5870) / 8GB RAM / หน้าจอแบ็คลิตไฟ LED ... ',
#  'ปัญหาที่ใหญ่ที่สุดคือกล่องไม่มีคำแนะนำ ',
#  'เมื่อเปรียบเทียบกับพีซีสเป็คในทำนองเดียวกันเครื่องนี้มีค่าที่ดีสร้างได้ดีและทำงานได้ง่ายนอกกรอบ ',
#  'หน้าจอมีความชัดเจนและระบบตอบสนองได้ดีมาก ',
#  'มันใช้งานง่ายและฉันได้สั่งซอฟต์แวร์และอุปกรณ์เพิ่มเติมสำหรับแล็ปท็อป Rolls Royce ใหม่ของฉัน ',
#  'มันอาจจะเป็นสิ่งที่ลึกเข้าไปใน Windows เพราะฉันไม่สามารถสร้างภาพดิสก์บนฮาร์ดไดรฟ์ของฉันได้ ',
#  'แทร็กแพดสำหรับฉันคือสิ่งที่โดดเด่นจริงๆคุณสามารถทำสิ่งต่าง ๆ ได้หลายอย่างขึ้นอยู่กับจำนวนนิ้วที่คุณใช้บนแผ่นแทร็คแอปเปิ้ลคิดที่ยอดเยี่ยม! ',
#  'ตอนนี้ฉันไม่ได้พยายามใช้สิ่งนี้เนื่องจากไดรฟ์ดิสก์ถูกแทนที่และหลังจากนำกลับไปที่ทีม Geek ฉันพบว่าพวกเขาไม่ได้ใช้ไดรฟ์ที่ถูกต้องเมื่อพวกเขาเปลี่ยนทีมแรกดังนั้นกลับมาเพื่อให้ถูกต้องขับ . ',
#  'ก่อนอื่นคุณจะค้นพบว่าโปรแกรมการประมวลผลคำที่เรียกว่า Appleworks ไม่ค่อยแปลอย่างสมบูรณ์แบบบนคอมพิวเตอร์ของคนอื่น ๆ ถ้ามันแปลเลย ',
#  'แบตเตอรี่ไม่สามารถอัพเกรดเป็นแบตเตอรี่ที่มีอายุการใช้งานได้นานขึ้น ',
#  'Apple มีชื่อเสียงและเป็นที่รู้จักกันดีในเรื่องการใช้งานง่าย ',
#  'แล็ปท็อปที่ส่งคืนสำหรับการซ่อมแซมครั้งที่ 3 และกลับมาพร้อมกับปัญหาก่อนหน้านี้ได้รับการแก้ไข (ยกเว้นการย่างลำโพง) แต่หน่วยเริ่มล็อคระหว่างการใช้งานและในที่สุดก็จะไม่ทำงานเลย ',
#  'รักกราฟิกโปรแกรมที่ยอดเยี่ยม (รวมถึง GarageBand) และพื้นหลังเริ่มต้นที่ยอดเยี่ยมจริงๆ ',
#  'หน้าจอแป้นพิมพ์และเมาส์: หากคุณไม่เห็นว่าตัวเองใช้จ่ายเงินพิเศษเพื่อกระโดดขึ้นไปบนหน้าจอที่สวยงามของ MAC แป้นพิมพ์แบ็คบอร์ดแบ็คไลท์เกาะที่ตอบสนองได้ ',
#  'โดยรวมแล้วฉันมีการเปลี่ยนแปลงครั้งใหญ่ที่ Mac ของฉันทำงานได้อย่างรวดเร็วเมื่อเทียบกับพีซีเครื่องเก่าของฉัน ',
#  'เมื่อฉันได้รับคอมพิวเตอร์กลับมาและ Realizwed มันก็ยังไม่ถูกต้อง HP บอกฉันว่ามันไม่รับประกันและตอนนี้มันเป็นปัญหาของฉัน ',
#  'มันมาพร้อมกับเว็บแคมที่สร้างขึ้นซึ่งยอดเยี่ยมเพราะฉันสามารถเห็นการสื่อสารกับสมาชิกในครอบครัวของฉันกลับบ้าน ',
#  'มันปลอดภัยและง่ายต่อการสำรวจ ',
#  "ฉันเบื่อหน่ายเล็กน้อยที่ซื้อ MacBook อีก 13 '' เกือบ 2 ปีต่อมา แต่ดูเหมือนว่า MacBooks รุ่นใหม่ได้รับกราฟิกการ์ดสายปัจจุบันในเวลานี้ ",
#  'พวกเขาเป็นระบบที่ง่ายที่สุดในการเรียนรู้เกี่ยวกับคอมพิวเตอร์ด้วย ',
#  'การ์ดวิดีโอนั้นยอดเยี่ยมสำหรับสื่อและสูงกว่าค่าเฉลี่ยสำหรับการเล่นเกม แต่ไม่ใช่ตัวเลือกแรกของนักเล่นเกม ',
#  'เห็นได้ชัดว่ามีข้อบกพร่องในการผลิตบางสิ่งบางอย่างที่มีปริมาณของความร้อนวาง ',
#  'การจดจำใบหน้าของ Asus ไม่ได้ผลและการเข้าสู่ระบบของ Windows ก็ไม่เหมือนกัน ',
#  'Windows Vista ทำให้คอมพิวเตอร์เครื่องนี้ใช้งานไม่ได้สำหรับบริการออนไลน์ ',
#  'ฉันติดต่อ Acer และพวกเขากำลังให้ดีวีดีการกู้คืนฟรีฉันดังนั้นอย่าไปและจ่ายเงินให้พวกเขาเพียงแค่ขอพวกเขาและพวกเขาควรให้พวกเขากับคุณ ',
#  'ตอนนี้เมื่อฉันสั่งซื้อฉันไม่ได้ไปอย่างเต็มรูปแบบสำหรับเว็บแคมหรือคีย์บอร์ดเต็มฉันต้องการบางอย่างสำหรับพื้นฐานของการพกพาง่ายเมื่อฉันใช้ไม้ค้ำหรือรถเข็นและกระเป๋ากระเป๋าเป้สะพายหลัง ',
#  'สามารถฟังเพลงของฉันและดูวิดีโอของฉันได้อย่างง่ายดายและด้วยการแสดงที่ยอดเยี่ยม ',
#  'การแสดงนั้นยอดเยี่ยม ',
#  'จอแสดงผลนั้นเกินความน่ากลัว ',
#  'แทบจะไม่มีหน่วยความจำใด ๆ ในฮาร์ดไดรฟ์ของคอมพิวเตอร์ ',
#  'แล็ปท็อป preformed ค่อนข้างดี ',
#  'นาทีที่คุณยิงมันให้ดีและง่ายต่อการใช้งานของผู้ใช้ที่ง่ายมาก ',
#  'จริง ๆ แล้วฉันติดต่อโตชิบาก่อนที่ฉันจะเริ่มมีปัญหาและได้รับการวิ่งไปรอบ ๆ หลังจากที่ฉันจัดหาหมายเลขซีเรียลเพื่อที่จะชะลอการส่งแล็ปท็อปจนกระทั่งหลังจาก Warrenty หมดอายุ ',
#  'หลังจากเปลี่ยนฮาร์ดไดรฟ์แล้วแบตเตอรี่ก็หยุดทำงาน (ใช้งาน 3 เดือน) ซึ่งน่าหงุดหงิด ',
#  'ฉันชอบหน้าจอที่มองเห็นได้ง่ายและใช้งานได้ดีสำหรับการทำงาน Persoal หรือเพียงแค่เล่น ',
#  'กราฟิกที่ยอดเยี่ยม! ',
#  'Pro เป็นผลิตภัณฑ์ที่ยอดเยี่ยมฉันหวังว่ารุ่น 13 นิ้วจะมาพร้อมกับโปรเซสเซอร์ Intel I และมีขอบที่สะดวกสบายกว่า (ขอบเจ็บข้อมือของฉัน) ',
#  'ข้อเสียเปรียบอย่างหนึ่งที่ฉันสังเกตเห็นคือคุณภาพเสียงผ่าน USB ',
#  'อายุการใช้งานแบตเตอรี่ดูดน้ำจากแล็ปท็อปของฉันและเมื่อแบตเตอรี่อายุการใช้งานหมดไปเราก็อยู่ที่นั่นมากสำหรับการรับประกันที่ครอบคลุมผลิตภัณฑ์ทั้งหมดที่เราซื้อ ',
#  'ฉันมี Mac อีกตัว แต่มันช้าเนื่องจากระบบปฏิบัติการเก่า ',
#  'เป็นเรื่องดีที่มีแล็ปท็อประดับสูงกว่า แต่นี่เหมาะกับงบประมาณของฉันและคุณสมบัติที่ฉันต้องการ ',
#  'รู้สึกผิดหวังที่พบว่าแบบจำลองได้ถูกยกเลิกอย่างเห็นได้ชัดเพราะปัญหาเมนบอร์ดที่รู้จักกันดี ',
#  'นอกจากนี้ลำโพงยังไม่ดังมาก แต่เป็นเน็ตบุ๊ก ',
#  'รักแล็ปท็อปราคาที่ยอดเยี่ยมสำหรับสิ่งที่คุณได้รับ! ',
#  'ผู้สนับสนุนหลักที่นำฉันไปสู่ MAC คือแง่มุมศิลปะ ',
#  'ดังนั้นฉันจึงตัดสินใจที่จะไม่ซื้อผลิตภัณฑ์ HP อื่น (Compaq อายุห้าขวบของฉัน) กินเวลา 5 ปีก่อนที่ฮาร์ดไดรฟ์จะชน ',
#  'ฉันรู้ว่าทุกคนคิดว่าแม็คมีราคาแพงเกินไปและเกินจริง แต่เมื่อคุณผ่านค่าใช้จ่ายเริ่มต้นที่คุณจะพบว่าพวกเขาคุ้มค่ากับเงินทุกเพนนี (นอกจากนี้ยังมีแผนการจัดหาเงินทุนที่ดีที่สุดเสมอ ',
#  'ฉันชอบแทร็กแพดแบบมัลติทัช ',
#  'HP มีความสนใจในการขายการรับประกันเพิ่มเติม (ซึ่งมีค่าใช้จ่ายสูงกว่า Netbook ใหม่) จากนั้นพวกเขาก็ช่วยหรือแก้ไข ',
#  "ซอฟต์แวร์ไม่มากเกินไป `` ขยะ '' ที่จะลบออก ",
#  'ระบบกำลังลดลงประมาณ 20 % ของประสิทธิภาพเนื่องจากสิ่งนั้น ',
#  'ความแตกต่างในแป้นพิมพ์ Apple จากแป้นพิมพ์ของพีซีใช้เวลาเล็กน้อยในการทำความคุ้นเคย แต่โดยรวมแล้วมันคุ้มค่า! ',
#  'ปัญหาเพียงอย่างเดียวคือมันช้าไปหน่อยและฉันก็แก้ไขได้โดยการเพิ่ม RAM มากขึ้น ',
#  'ฮาร์ดไดรฟ์ชนเช่นกันและฉันต้องซื้อสายไฟใหม่ ',
#  'อีกปัญหาที่ฉันมีคือแบตเตอรี่ ',
#  'MacBook Pro ของฉันทำงานเหมือนความฝันมันไม่เคยร้อนเกินไปหรือแม้แต่อุ่นเล็กน้อยสำหรับเรื่องนั้น ',
#  'ฉันได้รับคำชมมากมายเกี่ยวกับขนาดของมันและการพูดในฐานะคนที่เดินทางบนรถบัสเป็นประจำฉันสามารถยืนยันถึงความจริงที่ว่านี่เป็นคอมพิวเตอร์ขนาดที่สมบูรณ์แบบหากคุณถูก จำกัด อยู่ที่ความกว้างของร่างกายสำหรับห้องคอมพิวเตอร์ ',
#  'พกพาง่ายสามารถนำไปได้ทุกที่สามารถเชื่อมต่อกับเครื่องพิมพ์ชุดหูฟัง ',
#  'เมื่อฉันได้รับแล็ปท็อปของฉันกลับมาหลังจากอินสแตนซ์แรกนี้มันใช้ได้ดีสักหน่อยจากนั้นฉันก็เริ่มปัญหาการส่งออกอีกครั้งทุกอย่างจากโปรแกรมและไดรเวอร์ที่ล้มเหลวอีกครั้งไปจนถึงการเปิดเครื่องโดยไม่มีเหตุผลปัญหา . ',
#  'รักที่ไม่ต้องใช้พื้นที่เหมือนคอมพิวเตอร์ทั่วไป ',
#  'ดังนั้นฉันจึงนำมันกลับไปที่ร้าน Apple และพวกเขาพวกเขา Narcissist Genius Bar) แก้ไขโดยการรีเซ็ตพัดลมเมื่อบูตขึ้น ',
#  'เมาส์บนแผ่นปุ่มด้านซ้ายมักจะติดอยู่เสมอ ',
#  'เราใช้เครื่องมือในตัวบ่อยครั้ง iTunes เปิดเกือบทุกวันและใช้งานได้ดีกับ iPhone ของฉัน ',
#  'ขนาดของฉันช่วยฉันได้ค่อนข้างน้อยโดยที่ฉันสามารถใส่มันในกระเป๋าเป้สะพายหลังเต็มแล้วและใช้มันในร้านอาหารที่อาหารบนโต๊ะใช้พื้นที่นานมาก ',
#  'คุณภาพที่แท้จริงในราคาที่ดี! ',
#  'โปรแกรมที่มาพร้อมกับระบบการทำงานของเสือดาวนั้นเพียงพอสำหรับคนทั่วไปที่จะเรียกใช้พื้นฐานทั้งหมด ',
#  "แล้วฉันควรจะทำอย่างไร?ศูนย์บริการ LG ไม่สามารถให้บริการ `` `'' เมื่อเรียกว่าศูนย์บริการ` `'' ",
#  'วัสดุที่โปรนี้ทำจากดูเหมือนว่าดีกว่ารายละเอียดพีซีใด ๆ : อย่างที่ฉันบอกว่ามันทำงานได้ดีกว่าคอมพิวเตอร์เครื่องใด ๆ ที่ฉันเคยมีมาในอดีต ',
#  "หลังจากทำการวิจัยอย่างกว้างขวาง MacConnection มีราคาต่ำสุดใน 15 '' MBP i5 ",
# ...
#  'หน้าจอนั้นดีและภาพนั้นชัดเจนมากแป้นพิมพ์และความพอดีก็รู้สึกถูกต้อง ',
#  'แต่นั่งอยู่บนตักหรือบนโต๊ะข้างหน้าคุณมันดูใหญ่เกินกว่า (อาจเป็นเพราะฉันคุ้นเคยกับแท็บเล็ต Lenovo 10 ของฉันตอนนี้) บวกกับขนาดที่ดีถ้าฉันต้องการถอดปลั๊กแป้นพิมพ์ภายนอกเมาส์และตรวจสอบเพื่อนำติดตัวไปด้วยเมื่อฉันถ่ายรูปและวิดีโอ ',
#  'การคัดค้านเพียงอย่างเดียวที่ฉันมีคือหลังจากที่คุณซื้อระบบ Windows 7 เป็นผู้เริ่มต้นและค่าใช้จ่ายสำหรับการอัพเกรด ',
#  'ล้อที่เปิดระดับเสียงขึ้นและลงไม่ทำงานแบบเรียลไทม์ ',
#  'ฉันไม่สามารถมีความสุขกับบริการหรือผลิตภัณฑ์ได้ ',
#  'ฉันทำงานด้านการถอดความที่ด้านข้างและแป้นพิมพ์ Flatline ทำให้การพิมพ์ง่ายและรวดเร็วเช่นกัน ',
#  'ลำโพงไม่ได้ฟังดูดีขนาดนั้น ',
#  "`` การละเมิด '' คือฉันผลักปลั๊กไฟให้หนักเกินไป ",
#  'ความละเอียดบนหน้าจอเกือบจะบริสุทธิ์ HD ',
#  'Internet Explorer ช้ามากตั้งแต่เริ่มต้น ',
#  'พอร์ตพลังงาน AC จะหลวมเมื่อเวลาผ่านไป ',
#  'ในฐานะผู้ใช้พีซีฉันจะยอมรับว่า MacBook Pro มีระบบการทำงานที่ดีกว่าซึ่งฉันพบว่าตัวเอง `` การทำงานให้เสร็จเร็วขึ้น ',
#  'ไม่มีหมายเลขคีย์ทองในการติดตั้งโปรแกรมคุณต้องใช้หมายเลขซีเรียลที่ไม่ยอมรับและจากนั้นสิ่งต่าง ๆ ก็มีข้อ จำกัด เนื่องจากการทำงานเพราะพวกเขาดีในช่วงเวลาสั้น ๆ เท่านั้น ',
#  'และพวกเขาแทนที่แหล่งจ่ายไฟขนาดเล็กที่มีน้ำหนักเบาตามหลักสรีรศาสตร์ด้วยแหล่งจ่ายไฟที่ชั่งน้ำหนักมากกว่าเครื่องเอง ',
#  'เพลิดเพลินไปกับแรงโตชิบและความทนทานที่ไม่มีใครเทียบได้ ',
#  "ซึ่งเป็นสิ่งที่ยอดเยี่ยมฉันกำลังดำเนินธุรกิจ Vista และทำคะแนน 5.x ในดัชนีฉันไม่เคยเห็นเครื่อง Windows มีคะแนนรวมใน 5 ' ",
#  'เราชอบขนาดของหน้าจอแม้ว่ามันจะยังมีน้ำหนักเบาและง่ายต่อการเล่น ',
#  'แบตเตอรี่ไม่สามารถถูกแทนที่ได้ ',
#  'ฉันไม่เคยมีขนาดใหญ่เลยในการดาวน์โหลดอะไรเลยดังนั้นฉันจึงไม่กังวลเกี่ยวกับการรับไวรัสรวมถึงฉันคิดว่าฉันได้รับการปกป้องจากนอร์ตัน ',
#  'อินเทอร์เน็ตถูกล็อคและแข็งตัวทุกครั้งที่พยายามใช้และพรอมต์คำสั่งจะไม่ทำงานเลย ',
#  'ซอฟต์แวร์และความเร็วของมันทำให้สามารถทำสิ่งที่น่าอัศจรรย์ได้ ',
#  'ไม่สามารถติดตามฉันได้และในที่สุดฮาร์ดไดรฟ์ก็ออกไป ',
#  'ฉันประทับใจมากที่สุดกับการเขียนโปรแกรมรวมถึง iPhoto ',
#  'ลำโพงเล็กเกินไปที่จะใช้งานจริง ',
#  'ฉันอัพเกรดมันเป็น 2GB ฉันมีความสุขมากกับมัน ',
#  'พวกเขาควรรวมหน่วยความจำเพิ่มเติมไว้ในคอมพิวเตอร์หากพวกเขารู้ว่า Vista จะทำงานช้า ',
#  'อายุการใช้งานแบตเตอรี่อาจดีขึ้น แต่โดยรวมสำหรับราคาและชื่อเสียงของโตชิบาสำหรับแล็ปท็อปมันยอดเยี่ยมมาก! ',
#  'แบตเตอรี่ไม่เคยมีค่าใช้จ่ายนานกว่าหนึ่งชั่วโมงและภายในสองเดือนหยุดถือการชาร์จนานกว่าสิบนาที ',
#  'หลังจากการรับประกันหมดอายุฮาร์ดไดรฟ์ก็ไม่ดีและมันจะมีค่าใช้จ่ายมากขึ้นในการแก้ไขแล้วเพื่อแทนที่ ',
#  'รายการไอคอนที่เรียบร้อยและเป็นระเบียบคือการเปลี่ยนแปลงต้อนรับจากไอคอนเดสก์ท็อปที่ยุ่งเหยิงและสับสน ',
#  'เห็นได้ชัดว่าดี - สร้างและงดงามให้ดู i5 MacBook Pro เป็นการผสมผสานที่ชนะของราคาและประสิทธิภาพ ',
#  'Apple Care ไม่เคยทำให้ฉันล้มเหลวและฉันคาดหวังว่ามันจะเหมือนกันสำหรับคอมพิวเตอร์เครื่องนี้เช่นกัน ',
#  'แล็ปท็อปโตชิบาที่ฉันใช้นั้นใช้งานง่ายกว่าที่ฉันเคยลอง ',
#  'ฉันชอบขนาดแป้นพิมพ์ฟังก์ชั่น ',
#  'เมาส์เป็นวิธีที่ไวเกินไป ',
#  'นอกจากนี้ฉันออก RMA ทดแทนสำหรับพิกเซลที่ตายแล้วสองสามตัวในโซนบนของหน้าจอซึ่งเป็นที่สังเกตได้สำหรับฉัน ',
#  'เพื่อนของฉันรายงานสมุดบันทึกที่น่าประหลาดใจในประสิทธิภาพคุณภาพของภาพและความสะดวกในการใช้งาน ',
#  'โปรเซสเซอร์ i3 ดูเหมือนจะไม่ร้อนและแฟน ๆ ก็ไม่ค่อยเปิด ',
#  'ดูว่ามันมาถึงแล็ปท็อปที่คุณซื้อและรับเพียงระบบปฏิบัติการปกติพร้อมการทดลองที่ต้องต้องการสิ่งที่ควรมาพร้อมกับมัน ',
#  'สิ่งเดียวที่ฉันไม่เข้าใจคือความละเอียดของหน้าจอไม่สูงพอสำหรับบางหน้าเช่น Yahoo!จดหมาย. ',
#  'สะดวกมากเมื่อคุณเดินทางและอายุการใช้งานแบตเตอรี่ยอดเยี่ยม ... ',
#  'เครื่องจักรช้าในการบูตและบางครั้งล่มอย่างสมบูรณ์ ',
#  'ความสว่างของหน้าจอจะปรับโดยอัตโนมัติ ',
#  'นอกจากรูปลักษณ์ที่ยอดเยี่ยมแล้วมันเป็นเครื่องจักรที่ยอดเยี่ยม ',
#  'เสียงนั้นเงียบไปหน่อยถ้าคุณอยู่บนเครื่องบินสิ่งนี้สามารถเอาชนะได้อย่างง่ายดายด้วยโทรศัพท์หัวที่ดี ',
#  'ขนาดและน้ำหนักที่เหมาะสมสำหรับการพกพา ',
#  'อายุการใช้งานแบตเตอรี่ไม่ได้ติดตามการเรียกร้อง แต่ฉันก็คิดว่า MacBook อยู่ข้างหน้าอย่างมากจากส่วนที่เหลือของแพ็ค ',
#  'การสะท้อนแสงของจอแสดงผลเป็นเพียงความไม่สะดวกเล็กน้อยหากคุณทำงานในสภาพแวดล้อมที่มีแสงสว่างเช่นฉัน (ฉันชอบมันมืด) หรือถ้าคุณสามารถหมุนความสว่างได้ ',
#  'ข้อร้องเรียนหนึ่งของฉันกับแล็ปท็อปนี้คือฉันสังเกตเห็นเสียงฟัซซี่อิเล็กทรอนิกส์ที่ออกมาจากแจ็คหูฟังเมื่อเสียบหูฟัง ',
#  'ในขณะที่มันได้รับการจัดอันดับสูงฉันจะชอบไหม?ฉันลองแป้นพิมพ์ที่ร้านและดูเหมือนว่าโอเค ',
#  'รักษาตัวเองด้วยแล็ปท็อปคุณภาพที่มีราคาแพงกว่าเช่น Sony, Apple หรือ Toshiba ',
#  '(ไม่มีปัญหากับการสั่งซื้อหรือการจัดส่งโดยวิธีการ ',
#  'และ RAM (สิ่งที่ทำให้เร็วขึ้น) มาถึง 2 กิ๊กสำหรับประสิทธิภาพสูงเพื่อจัดการกับสิ่งต่าง ๆ มากขึ้นในครั้งเดียวและท่องเว็บให้เร็วขึ้นกว่าเดิมมาก ',
#  'ฉันแก้ไขและเบิร์นเป็นดีวีดีวิดีโอจำนวนมากดังนั้นฉันจึงไม่สามารถอยู่กับไดรฟ์ที่ไม่ทำงานได้ ',
#  'เร็วและยอดเยี่ยม! ',
#  'ราคาสมเหตุสมผลมากและทำงานได้ดีมากนอกกรอบ ',
#  'ในขณะที่คีย์บอร์ดเองก็ไม่เป็นไรแผ่นรอบ ๆ เป็นพลาสติกราคาถูกและทำเสียงกลวงเมื่อใช้ปุ่มคำสั่งเมาส์ ',
#  'มีคุณสมบัติและประโยชน์ที่ยอดเยี่ยมมากมายสำหรับ MacBook ใหม่! ',
#  'สิ่งเดียวที่ฉันสามารถพูดได้คือทัชแพดไม่ได้ทำงานเหมือนมันควรจะตลอดเวลา ',
#  'ด้วยเหตุผลบางอย่างที่คอมพิวเตอร์ไม่รู้จักระบบปฏิบัติการ ',
#  'แทร็กแพดนั้นง่ายต่อการเรียนรู้และนำทาง ',
#  'แอพพลิเคชั่นเปิดในไม่กี่วินาทีและไม่มีความล่าช้าอาการสะอึกหรือช่วงเวลาที่น่าอึดอัดใจเมื่อคุณสงสัยว่าคอมพิวเตอร์ของคุณออกไปดื่มชาหรือไม่ ',
#  'ฉันตอบว่าฉันไม่มีคอมพิวเตอร์เครื่องเก่าและด้วยวิธีนี้ฉันจะสูญเสียข้อมูลในฮาร์ดไดรฟ์ของฉัน ',
#  'อีกครั้งในเดือนกุมภาพันธ์คอมพิวเตอร์ของฉันล้มเหลวอย่างสมบูรณ์จนถึงจุดที่ไม่สามารถโหลด windows ได้ดังนั้นฉันจึงติดต่อ Acer เพื่อให้ได้รับการแก้ไขผ่านสงครามของฉันและใช้เวลาประมาณ 3 วันในการต่อสู้ทางโทรศัพท์กับตัวแทนและดูเหมือนว่าไม่มีใครพูดภาษาอังกฤษได้ ',
#  'แม้ว่าคอมพิวเตอร์จะมีขนาดใหญ่กว่า แต่ก็ไม่ได้ทำให้แป้นพิมพ์ใหญ่ขึ้น ',
#  'มันไม่ได้ช้าบนอินเทอร์เน็ต แต่มันช้าโดยทั่วไป ',
#  'มันมี RAM เพียงพอที่จะทำงานได้อย่างราบรื่นและมีความจำเพียงพอที่จะตอบสนองความต้องการของฉัน ',
#  'จริง ๆ แล้วฉันเชื่อว่าปัญหานี้เกิดขึ้นกับการ์ดกราฟิกของ Nvidia แต่ก็ยังต้องได้รับผลตอบแทน ',
#  'มันง่ายมากที่จะพิมพ์และให้ความรู้สึกที่ดี - นอกเหนือจากคุณสมบัติเพิ่มเติมที่แป้นพิมพ์มีแสงสว่าง ',
#  'ความรู้สึกของเครื่องนี้เมื่อเทียบกับ MacBook เก่านั้นเหนือกว่ามาก ',
#  'ในเวลาอันควรฉันจะถอดฮาร์ดดิสก์ออกจาก MacBook Pro ใหม่นี้และทิ้งไว้ในที่ที่มันเป็น - ในถังขยะ ',
#  'พวกเขาสลายตัวบ่อยเท่าที่พีซีทำและเหตุผลเดียวที่พวกเขาไม่ได้รับไวรัสเพราะไม่มีใครทำไวรัสสำหรับพวกเขาMac พวกเขาไม่มีอยู่จริง ',
#  'คุณภาพการสร้างโดยรวมของหน่วยนั้นยอดเยี่ยมและเธอแนะนำให้คนอื่นมองหาเน็ตบุ๊ก ',
#  'การซ่อมแซมถูกทำอย่างรวดเร็วแม้ว่าฉันจะต้องพูด แต่ครั้งที่สองที่พวกเขาส่งไปยังที่อยู่ที่ไม่ถูกต้องและใช้เวลาเกือบหนึ่งสัปดาห์เพื่อให้พวกเขาได้รับมันให้ฉัน ',
#  'มันเร็วและฉันไม่ได้มีปัญหากับการเชื่อมต่ออินเทอร์เน็ตหรือปัญหาอื่น ๆ ',
#  'ฉันประทับใจมากกับคุณภาพและประสิทธิภาพในราคาคอมพิวเตอร์ ',
#  'มันใช้งานง่ายมากฉันใช้มันมากกว่าเดสก์ท็อปของฉัน ',
#  'ฉันยังมีปัญหากับทัชแพดที่ทำให้ตัวชี้เมาส์กระโดดไปทั่วหน้าจอ ',
#  'ไม่ว่าจะด้วยวิธีใดแป้นพิมพ์ก็ไม่น่าพอใจ ',
#  'ฉันต้องบอกว่าตั้งแต่ฉันซื้อ Mac ของฉันฉันไม่เคยกลับไปที่หน้าต่างใด ๆ ',
#  'ฉันเอาไปที่ร้าน Apple และเดาอะไร?พวกเขาแก้ไขมันไม่มีค่าใช้จ่ายจากกระเป๋า ',
#  'คุณภาพการออกแบบวิศวกรรมและการรับประกันนั้นเหนือกว่า - ครอบคลุมความเสียหายจากการทิ้งแล็ปท็อป ',
#  'แอพพลิเคชั่นนั้นหาง่ายและซ้อมรบง่ายกว่าคอมพิวเตอร์เครื่องอื่น ๆ ที่ฉันเคยเป็นเจ้าของ ',
#  'หน้าจอขนาดใหญ่ช่วยให้คุณมีตัวเลือกในการดูภาพยนตร์หรือรายการทีวีอย่างสะดวกสบายในคอมพิวเตอร์ของคุณแทนที่จะซื้อทีวีเพิ่มเติมสำหรับห้องพักหอพักของคุณ ',
#  'แล็ปท็อปที่ยอดเยี่ยมสำหรับโรงเรียนใช้งานง่ายสำหรับผู้เริ่มต้นในบ้าน ',
#  '4) แล็ปท็อปยังไม่ทำงานหน้าจอสีน้ำเงินภายในหนึ่งสัปดาห์ ... ',
#  'สิ่งเดียวที่ไม่สมบูรณ์แบบเกี่ยวกับเน็ตบุ๊กนี้คือลำโพงพวกเขาไม่ดังเลย แต่ฉันคาดหวังว่า ',
#  'แน่นอนว่าฉันตรวจสอบเน็ตบุ๊กอื่น ๆ และบานพับของพวกเขาชัดเจนขึ้นและฉันยังแสดงให้เห็นถึงความแตกต่างระหว่างเน็ตบุ๊กกับคนอื่น ๆ ',
#  'ไม่ได้ผลเมื่อจัดส่งจาก Walmart.com แต่เข้าไปในร้านค้าและแลกเปลี่ยนสำหรับแล็ปท็อปที่ใช้งานได้ (Make/Model เดียวกัน) ',
#  'โปรแกรมทั้งหมด (คำปราศรัย, หน้า, ตัวเลข) มีตัวเลือกในการบันทึกเอกสารของคุณเป็น Microsoft ที่เข้ากันได้ซึ่งไม่จำเป็นต้องใช้จริง ',
#  'แน่นอนว่าค่าใช้จ่ายเริ่มต้นของกระเป๋าจะยิ่งใหญ่กว่า แต่ไม่ควรห้ามไม่ให้ใครจากความจริงที่ว่าเครื่องเหล่านี้ทำงานเหมือนไม่มีใครในโลกและเมื่อฉันคำนึงถึงเงินทั้งหมดที่ฉันเสียไปกับทีม Geek และแพทช์ล่าสุดเพื่อกำจัดพีซีที่ถูกรบกวนของฉันมันอาจจะออกมาแม้แต่แค่ไหน ',
#  "สิ่งที่ดีที่สุดที่ต้องทำคือสร้างคอมพิวเตอร์ของคุณเอง แต่ถ้าคุณไม่เหมือน บริษัท ที่อนุญาตให้คุณเลือกส่วนประกอบจะดีกว่าและในราคาเดียวกันคุณจะได้รับคอมพิวเตอร์ที่เปรียบเทียบกับหนึ่งใน Apple $ 2000ระบบและถ้าคุณ Google `` คูปอง Dell '' คุณสามารถค้นหารหัสที่ลดราคาจำนวนมาก ",
#  'ไม่มีไดรฟ์ซีดีบนคอมพิวเตอร์ซึ่งเอาชนะจุดประสงค์ในการเก็บไฟล์บนซีดี ',
#  'น่าเสียดายที่คุณภาพของ Apple ยังคงเลื่อนไปอย่างต่อเนื่อง ',
#  'ฉันเชื่อว่าคุณภาพของ Mac นั้นคุ้มค่ากับราคา ',
#  'บางครั้งคุณจะขยับนิ้วและตัวชี้จะไม่เคลื่อนไหว ',
#  "MacBook Pro 13 '' เหมาะกับงบประมาณของฉันและด้วยการจัดส่งฟรีและไม่มีภาษีไปยัง CA นี่คือราคาที่ดีที่สุดที่เราจะได้รับสำหรับผลิตภัณฑ์ที่ยอดเยี่ยม ",
#  'ฉันจะให้คะแนนคอมพิวเตอร์นี้ที่ 5 ดาว แต่เมื่อพิจารณาว่ามันมีช่วงชีวิตสั้น ๆ ฉันสามารถให้ได้ 1 และขอร้องให้ทุกคนที่ดูแล็ปท็อปอยู่ห่างจากเครื่องนี้ ',
#  'ฉันยังชอบการออกแบบรูปลักษณ์ความรู้สึกและคุณสมบัติของฉัน Toshiba นั้นยอดเยี่ยม ',
#  'นอกจากนี้ยังดีมากสำหรับนักศึกษาที่ต้องการคอมพิวเตอร์ที่เชื่อถือได้และใช้งานง่าย ',
#  'มีเพียงสิ่งอื่นเท่านั้นคือถ้าคุณใช้สิ่งนี้สำหรับการสร้างเอกสาร Apple ไม่ได้ให้คำประมวลผลคำใด ๆ (เช่น Works for Windows) แต่ iWork ราคาถูกเมื่อเทียบกับสำนักงาน ',
#  'มันเบาและแบตเตอรี่ใช้เวลานานมาก ',
#  'และเมื่อถึงจุดหนึ่งพวกเขาตำหนิฉันในการติดตั้งแท่งหน่วยความจำที่ไม่ดีเมื่อฉันอัปเกรดหน่วยความจำเป็นครั้งแรกในระหว่างการซื้อแล็ปท็อป (ฉันซื้อแท่งหน่วยความจำที่พวกเขาแนะนำ) ',
#  'ภายนอกปุ่มบนคีย์บอร์ดของฉันกำลังตกลงมาหลังจากใช้งานไม่กี่สีกำลังถูปุ่มด้านล่างแผ่นรองเมาส์และที่ที่รักษามือของฉันนั่งและหน้าจอมีแสงจ้าที่น่ากลัว ',
#  'ครั้งต่อไปที่ฉันมีปัญหา Lightscribe ของฉันจะไม่ได้ผล ',
#  'ทัชแพดมีความอ่อนไหวอย่างยิ่งซึ่งเป็นข้อเสียเปรียบเพียงอย่างเดียว ',
#  'นอกจากนี้ยังมาพร้อมกับแอพพลิเคชั่นที่มีประโยชน์มากเช่น iPhoto ว่าเป็นแอปพลิเคชั่นภาพถ่ายที่ดีที่สุดที่ฉันเคยมีมา ',
#  'คอมพิวเตอร์ Acer One ที่ฉันซื้อคือหน้าจอขนาด 17 นิ้วและมันยากที่จะหากระเป๋าแล็ปท็อปสำหรับมัน แต่ฉันชอบหน้าจอขนาดใหญ่บนมัน ',
#  'ฉันสามารถให้ทั้ง OSX และ Windows XP ทำงานในเวลาเดียวกัน! ',
#  'ดูเหมือนว่า Microsoft จะไม่สามารถซ่อมแซมปัญหามากมายของ Windows ได้ ',
#  'คุณสามารถโทรหา HP และพวกเขาต้องการให้คุณซื้อซอฟต์แวร์เพิ่มเติมเพื่อแก้ไข ',
#  'เป็นเรื่องง่ายที่จะนำทางและอัปเดตโปรแกรม ',
#  'โดยรวมแล้วเป็นประสบการณ์ที่น่าผิดหวังมากยกเว้นว่าฉันได้เรียนรู้ว่าทีม Geek นั้นดีแค่ไหนและยังบริการลูกค้า ',
#  'แล็ปท็อปมีน้ำหนักเบามากสามารถพกพาไปรอบ ๆ ได้อย่างง่ายดายในหนังสือที่เต็มไปด้วยหนังสือเรียนและมันก็เพิ่มน้ำหนักได้ ',
#  'ฉันยังไม่ชอบเสียงดังที่เกิดขึ้นหรือด้านล่างของคอมพิวเตอร์จะร้อนจริงๆ ',
#  'ฉันเคยมีแล็ปท็อป Dell ในอดีตและพวกเขาก็ส่งสิ่งของที่จำเป็นหรือพวกเขาส่งช่างซ่อมมาที่บ้านของฉันเพื่อแก้ไข ',
#  'ซอฟต์แวร์ที่มีข้อบกพร่อง ',
#  'คอมพิวเตอร์เครื่องนี้ท้าทายในการพกพาและจัดการ ',
#  'สายไฟออกมาทางด้านขวาสำหรับสายไฟและสายไฟออกมาด้านหน้าสำหรับหูฟัง/ไมค์บวกการเชื่อมต่อเครือข่ายทางด้านซ้ายทำให้การติดตั้งยุ่งมากโดยมีสายไฟไปทุกทิศทาง ',
#  'เว้นแต่คุณจะต้องการไม่สะดวกกับแหล่งจ่ายไฟที่ไม่ทำงานซึ่งคุณไม่สามารถหาสิ่งทดแทนได้เพราะพวกเขาทำให้สิ่งที่แนบมามีขนาดเล็กมาก ',
#  'มันเร็วกว่าเดสก์ท็อปของฉันมากซึ่งเป็น Core2 Quad ที่ทำงานที่ 2.83 GHz ',
#  'เป็นเรื่องดีที่รู้ว่าฉันสามารถระดมพลได้โดยไม่ต้องกังวลเกี่ยวกับอายุการใช้งานแบตเตอรี่ ',
#  'หน้าจอดีมุมมองด้านข้างค่อนข้างดี ',
#  'ความจริงที่ว่าหน้าจอตอบสนองต่อแสงรอบตัวคุณเป็นความหรูหราที่เพิ่มเข้ามา -เมื่อคุณทำงานรอบ ๆ คนอื่น ๆ ในพื้นที่มืดและต้องการความเป็นส่วนตัวหรือไม่อยากรบกวนพวกเขาด้วยแสงสว่างที่สดใสมันสะดวกมากที่จะมีสีเข้มกว่าหน้าจอที่เบากว่า ',
#  '3 สัปดาห์ผ่านไปและคอมพิวเตอร์ยังคงล่มและจะไม่เปิดแอปพลิเคชันใด ๆ ',
#  'ดูดี แต่ให้ความรู้สึกราคาถูกอย่างน่ากลัว ',
#  'ความรู้สึกของสิ่งนี้ดีกว่าโตชิบาเช่นกัน ',
#  'ฉันอยากจะแนะนำแล็ปท็อปนี้ให้กับทุกคนที่ต้องการรับแล็ปท็อปเครื่องใหม่ที่เต็มใจใช้เงินเพิ่มขึ้นเล็กน้อยเพื่อให้ได้คุณภาพที่ดี! ',
#  'ฉันอัพเกรดหน่วยความจำและแทนที่ผู้เริ่มต้น Windows 7 ฐานเพื่อชนะ 7 บ้านและมันก็ทำงานได้ดี ',
#  'ฉันไม่แน่ใจว่ามันเป็นไดรฟ์เองหรือไม่ ',
#  'นอกจากนี้ผู้ใช้คนหนึ่งกล่าวถึงว่าขอบของ MacBook นั้นคมชัดอย่างไรถ้าคุณมีเงินที่จะใช้จ่ายกับหนึ่งในกระสุนที่มีปัญหาดูเหมือนจะไม่เป็นปัญหา ',
#  'มันใช้งานง่ายแป้นพิมพ์ของมันรองรับมือขนาดใหญ่ได้อย่างง่ายดายและน้ำหนักก็ยอดเยี่ยม ',
#  'เรียกว่า Acer หลายครั้งพวกเขาต้องการให้ฉันจ่ายค่าจัดส่งเพื่อจัดส่งไปยังศูนย์ซ่อมของพวกเขา - ฉันรู้สึกผิดหวังมากเพราะเป็นคอมพิวเตอร์เครื่องใหม่! ',
#  'แบตเตอรี่ยาวมาก ',
#  'มีปัญหาในการหากรณีที่มันจะพอดี ',
#  'คอมพิวเตอร์เครื่องนี้ที่ฉันมีปัญหากับแป้นพิมพ์ที่สูญเสียฟังก์ชั่นแป้นพิมพ์ครึ่งหนึ่ง ',
#  'เมื่อฉันเรียก Sony การบริการลูกค้าก็ยอดเยี่ยม ',
#  'มันเป็นระบบที่มีความคล่องตัวมากขึ้นสำหรับการเพิ่มโปรแกรมโดยใช้อินเทอร์เน็ตและทำสิ่งอื่น ๆ ที่ทุกคนทำในคอมพิวเตอร์ ',
#  'คอมพิวเตอร์ของฉันแข็งตัวหลายครั้งมีปุ่มที่สุ่มจะล้มลงและแม้กระทั่งมีช่วงเวลาที่คอมพิวเตอร์จะปฏิเสธที่จะเปิดเลย ',
#  'ไม่แม้แต่รองเท้าเซฟโหมด ',
#  'นี่คือแล็ปท็อปขนาด 18 นิ้ว ',
#  'ฉันต้องจ่าย $ 100 สำหรับเครื่องชาร์จสากลสำหรับแล็ปท็อปราคาถูก $ 300 นี้ ',
#  'PowerPoint เปิดอย่างราบรื่นใน Apple และ Mac เชื่อมต่อกับโปรเจ็กเตอร์ได้อย่างง่ายดายจนเกือบจะน่ากลัว ',
#  '1. คุณไม่สามารถเปลี่ยนพื้นหลังเดสก์ท็อปของคุณได้ (สตาร์ทเตอร์ 7 ของหน้าต่างไม่รองรับฟังก์ชั่นนั้น) ',
#  'จากนั้นหลังจาก 4 เดือนหรือมากกว่านั้นเครื่องชาร์จหยุดทำงานดังนั้นฉันจึงถูกบังคับให้ออกไปซื้อฮาร์ดแวร์ใหม่เพื่อให้คอมพิวเตอร์เครื่องนี้ทำงานอยู่ ',
#  'จุดแข็ง: อืม - จุดอ่อนรูป: การ์ดวิดีโอที่ไม่ดี! ',
#  'คุณไม่สามารถรับการ์ดดาวเทียมได้ด้วยซ้ำซึ่งเป็นเหตุผลที่ฉันซื้อเพื่อเริ่มต้นด้วย ',
#  'มันเป็นทัชแพดที่แท้จริงไม่ใช่ของเล่นที่ฉันเห็นในแบรนด์อื่น ๆ ',
#  'ราคาและวัตถุประสงค์ยอดเยี่ยมมาก! ',
#  'การซูมที่ยอดเยี่ยม ',
#  'หน้าจอมีขนาดใหญ่และมีสีสัน แต่ไม่มีการแบ็คไลท์ LED ',
#  'ในความซื่อสัตย์ทั้งหมดหากมีคนกำลังมองหาแล็ปท็อปที่มีคุณภาพและเต็มใจที่จะจ่ายเงินให้กับแล็ปท็อปขนาดปกติมากกว่าแล็ปท็อปที่ถูกกว่าและน่าประทับใจน้อยกว่านั้นอย่าซื้อคอมพิวเตอร์เครื่องนี้ ',
#  'ทุกอย่างเกี่ยวกับคอมพิวเตอร์เครื่องนี้ใช้งานง่าย ',
#  'ที่แย่กว่านั้นสำหรับราคาที่ฉันจะได้รับ * netbook * ที่ดีกว่าเครื่องนี้ ',
#  'แป้นพิมพ์ก็ดีมากและมีความรู้สึกที่มั่นคง ',
#  'มันไม่ได้มีคุณสมบัติทั้งหมดที่ฉันคาดไว้ ',
#  'ไม่มีโชคถึงแม้ว่าฉันจะรอหลายชั่วโมงบน Machouse ที่เยี่ยมชมโทรศัพท์พวกเขาเริ่มต้นศูนย์บริการของพวกเขาลดลงเนื่องจากโทรศัพท์มากเกินไป (ยากที่จะเชื่อ) ',
#  'มีแป้นพิมพ์ย้อนกลับซึ่งเหมาะสำหรับการพิมพ์ในความมืด ',
#  'มันมีความทรงจำมากมายและอายุการใช้งานแบตเตอรี่ที่ยอดเยี่ยม ',
#  'ฉันได้พูดคุยกับตัวแทนบริการที่ Micro Center และแฟนสาวของเขามีปัญหาเดียวกันกับอะแดปเตอร์พลังของเธอดังนั้นมันจึงไม่ใช่แค่เหตุการณ์ที่โดดเดี่ยว!ซซ ',
#  'ฉันชอบโปรแกรมนี้มันเหนือกว่า Windows Movie Maker ',
#  'เขาเปลี่ยนฮาร์ดไดรฟ์ของเขาสองครั้งและ (แน่นอน) ต้องจ่ายค่าซอฟต์แวร์ป้องกันไวรัสทุกปี ',
#  'การซื้อครั้งนี้ทำให้ฉันสู่โลกของ MacBooks และฉันประทับใจกับสัญชาตญาณของการออกแบบความงามของผลิตภัณฑ์และความก้าวหน้าทางเทคโนโลยีที่ยอดเยี่ยมที่เกี่ยวข้อง ',
#  'ราคานี้ยอดเยี่ยมสำหรับรุ่นนี้ฉันวางแผนที่จะใช้มันสำหรับสื่อในห้องบันเทิง ',
#  'ฉันต้องเปลี่ยนแป้นพิมพ์ด้วยค่าใช้จ่ายของฉันด้วย ',
#  "ฉันให้พนักงานบอกฉันว่ารุ่นเก่าไม่ได้ทำให้เสียงพัดลมทำให้เป็นคอมพิวเตอร์ `` ที่แตกต่าง '' ",
#  'แม้แต่การรับประกัน! ',
#  'หน้าจอที่คมชัดอายุการใช้งานแบตเตอรี่ที่ยอดเยี่ยมและพื้นที่จัดเก็บมากมาย ',
#  'นอกจากนี้พี่สาวของฉันยังได้รับแล็ปท็อปเดียวกัน (เนื่องจากพวกเขาราคาถูกมาก) และหลังจาก 8 เดือนหน้าจอจะแยกออกจากครึ่งหนึ่งจากการใช้งานทุกวัน ',
#  'ดาวเทียมโตชิบาเป็นมากกว่าที่ฉันคาดไว้สำหรับราคา ',
#  'ฉันต้องปรับความไวของ mousepad ของฉันเพราะมันอ่อนไหวมาก ',
#  'คีย์บอร์ดเป็นความรู้สึกพลาสติกและเป็นรูพรุน ',
#  'แล็ปท็อปก่อนหน้านี้เป็นพีซียังคงมีอยู่ แต่ MacOS เป็นระบบปฏิบัติการที่สะอาดและราบรื่น ',
#  'ฉันชอบที่จะมีหมายเลขเครื่องคิดเลขเพิ่มเติมที่ตั้งค่าบนแป้นพิมพ์ซึ่งแล็ปท็อปส่วนใหญ่ไม่มี ',
#  'ฉันรักแอปเปิ้ลของฉันมันใช้งานง่ายและใช้งานง่าย ',
#  'แล็ปท็อปใช้งานได้ค่อนข้างง่ายแม้ว่าฉันจะซื้อ Macs สำหรับ Dummies ซึ่งมีมูลค่า $ 2 ',
#  'ไม่มีบทช่วยสอนบนหน้าจอ ',
#  'ทัชแพดเป็นหนึ่งในสิ่งที่ดีที่สุด ',
#  'นอกจากนี้เรายังใช้พันธุกรรมเพื่อให้เราสามารถเรียกใช้เครื่องเสมือนของ Windows XP Professional, Windows 7 Home Premium, Windows Server Enterprise 2003 และ Windows Server 2008 Enterprise ',
#  'วิธีที่โตชิบาจัดการกับการซ่อมแซมดูเหมือนจะแตกต่างกันไปบางคนระบุว่าพวกเขาถูกเรียกเก็บเงินสำหรับแม้แต่การแก้ไขอย่างไม่หยุดยั้งคนอื่น ๆ ได้ทำการซ่อมแซมเสร็จ 5 ครั้ง ']

# %%
dataset = ABSADataset(args, tokenizer, inputs=input_list[:10], targets=target_list)
# Out:
# c:\Workspace\Tutorial\BGCA\.conda\lib\site-packages\transformers\tokenization_utils_base.py:2263: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
def infer_new(args, dataset, model, tokenizer, name=None, is_constrained=False, constrained_vocab=None, keep_mask=False, **decode_dict):
    dataloader = DataLoader(dataset, batch_size=args.eval_batch_size, num_workers=4)

    if keep_mask:
        # can't skip special directly, will lose extra_id
        unwanted_tokens = [tokenizer.eos_token, tokenizer.unk_token, tokenizer.pad_token]
        unwanted_ids = tokenizer.convert_tokens_to_ids(unwanted_tokens)
        def filter_decode(ids):
            ids = [i for i in ids if i not in unwanted_ids]
            tokens = tokenizer.convert_ids_to_tokens(ids)
            sentence = tokenizer.convert_tokens_to_string(tokens)
            return sentence

    # inference
    inputs, outputs, targets = [], [], []
    
    model.eval()
    with torch.no_grad():
        for batch in tqdm(dataloader, desc='Generating'):
            if is_constrained:
                prefix_fn_obj = Prefix_fn_cls(tokenizer, constrained_vocab, batch['source_ids'].to(args.device))  # need fix
                prefix_fn = lambda batch_id, sent: prefix_fn_obj.get(batch_id, sent)
            else:
                prefix_fn = None

            outs_dict = model.generate(input_ids=batch['source_ids'].to(args.device),
                                        attention_mask=batch['source_mask'].to(args.device),
                                        max_length=128,
                                        prefix_allowed_tokens_fn=prefix_fn,
                                        output_scores=True,
                                        return_dict_in_generate=True,
                                        **decode_dict,
                                        )
            outs = outs_dict["sequences"]

            if keep_mask:
                input_ = [filter_decode(ids) for ids in batch["source_ids"]]
                dec = [filter_decode(ids) for ids in outs]
                target = [filter_decode(ids) for ids in batch["target_ids"]]
            else:
                input_ = [tokenizer.decode(ids, skip_special_tokens=True) for ids in batch["source_ids"]]
                dec = [tokenizer.decode(ids, skip_special_tokens=True) for ids in outs]
                target = [tokenizer.decode(ids, skip_special_tokens=True) for ids in batch["target_ids"]]

            inputs.extend(input_)
            outputs.extend(dec)
            targets.extend(target)

    # decode_txt = "constrained" if is_constrained else "greedy"
    # with open(os.path.join(args.inference_dir, f"{name}_{decode_txt}_output.txt"), "w") as f:
    #     for i, o in enumerate(outputs):
    #         f.write(f"{inputs[i]} ===> {o}\n")

    # return inputs, outputs, targets
    return inputs, outputs

# %%
input_infer, output_infer = infer_new(
        args, dataset, model, tokenizer, 
        # name=f"thai-pred",
        # is_constrained=True, 
        is_constrained=False, 
        constrained_vocab=prepare_constrained_tokens(tokenizer, args.task, args.paradigm),
    )


for x,y in zip(input_infer, output_infer):
    print(f'input text:{x}')
    print(f'predict(gene) text:{y}')
# Out:
# Generating:   0%|          | 0/1 [00:00<?, ?it/s]
# input text:ฉันชาร์จมันในเวลากลางคืนและข้ามสายไฟติดตัวไปด้วยเพราะอายุการใช้งานแบตเตอรี่ที่ดี
# predict(gene) text:<neu> battery <opinion> bad
# input text:มันมีคุณภาพสูงมี GUI นักฆ่ามีความเสถียรมากสามารถขยายได้สูงมีการใช้งานที่ดีมากใช้งานง่ายใช้งานง่ายและงดงามอย่างแน่นอน
# predict(gene) text:<pos> GUI <opinion> คุณภาพสูง <pos> GUI <opinion> бережs of <pos> use <opinion> easy
# input text:ง่ายต่อการเริ่มต้นและไม่ร้อนเกินไปเท่าแล็ปท็อปอื่น ๆ
# predict(gene) text:<pos> เริ่มต้น <opinion> ง่าย <pos> start <opinion> ง่าย
# input text:แล็ปท็อปที่ยอดเยี่ยมที่มีคุณสมบัติที่ยอดเยี่ยมมากมาย!
# predict(gene) text:<pos> คุณสมบัติ <opinion> ที่ยอดเยี่ยม
# input text:คืนหนึ่งฉันปิดสิ่งที่น่าประหลาดใจหลังจากใช้มันในวันถัดไปฉันเปิดเครื่องไม่มี GUI หน้าจอมืดทั้งหมดไฟคงที่ไฟฮาร์ดไดรฟ์คงที่และไม่กระพริบเหมือนปกติ
# predict(gene) text:<neg> GUI <opinion> น่าประหลาดใจ <neg> GUI <opinion> มืดทั้งหมดไฟ <opinion> hard <neg> ไฟ <opinion> horrible
# input text:อย่างไรก็ตามท่าทางแบบมัลติทัชและพื้นที่ติดตามขนาดใหญ่ทําให้ไม่จําเป็นต้องใช้เมาส์ภายนอก (เว้นแต่คุณจะเล่นเกมอีกครั้ง)
# predict(gene) text:<neg> เมาส์ภายนอก <opinion> ไม่จําเป็นต้องใช้
# input text:ฉันชอบวิธีที่ชุดซอฟต์แวร์ทั้งหมดทํางานร่วมกัน
# predict(gene) text:<neu> ชุดซอฟต์แวร์ <opinion> love <neg> software <opinion> workร่วมกัน
# input text:ความเร็วนั้นเหลือเชื่อและฉันก็พอใจมากกว่า
# predict(gene) text:<pos> ความเร็ว <opinion> เหลือเชื่อ <pos> ความเร็ว <opinion> พอใจ
# input text:ฉันแทบจะไม่สามารถใช้อุปกรณ์ USB ใด ๆ ได้เพราะพวกเขาจะไม่เชื่อมต่ออย่างถูกต้อง
# predict(gene) text:<neg> อุปกรณ์ USB <opinion> จะไม่สามารถใช้ <neg> USB <opinion> not connect
# input text:ในที่สุดเมื่อฉันมีทุกอย่างที่ทํางานกับซอฟต์แวร์ทั้งหมดของฉันที่ติดตั้งฉันเสียบอยู่ในหุ่นยนต์ของฉันเพื่อเติมเงินและระบบล่ม
# predict(gene) text:<neu> software <opinion> badบ
